# %%
pip install ../../
# Out:
# Processing /home/mehdi/Straph
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#   Created wheel for straph: filename=straph-0.3-py3-none-any.whl size=128029 sha256=79cae8b42178e1ad7207c4caee97653cab5319db343c70093a49705f98e71a77
#   Stored in directory: /tmp/pip-ephem-wheel-cache-z_z2azfi/wheels/a5/b6/52/18c617da8ab7981501f28a49d398fa4ccca532d1baece44b1e
# Successfully built straph
# ...
#   Attempting uninstall: straph
#     Found existing installation: straph 0.3
#     Uninstalling straph-0.3:
#       Successfully uninstalled straph-0.3
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.2.2 is available.
# ...

# %%
#sigmasv_links.sg
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,10)
import straph as sg
import straph.betweenness as bt
import straph.betweenness.volumes as vol
import straph.paths.meta_walks as mw
import operator

# %%
file_name = "examples/primary_school/primaryschool.csv"
entry_format = {"u_pos": 1, "v_pos": 2, "t_pos": 0}
config = {"delimiter": "\t", "ignore_header": False, "nodes_to_label": True, "time_is_datetime": False,
          "is_link_stream" : True}
sg.sort_csv(file_name, entry_format, **config)
S = sg.parser(input_file=file_name,
           input_format='csv',
           entry_format=entry_format,
           output_file="high_school_2013",
           output_format='sg',
           **config)
# Out:
# ...
# Writing CSV: 100%|██████████| 125773/125773 [00:00<00:00, 959370.83it/s]
# [WARNING] No link_duration provided, links durations are set to 0.
# Parsing CSV: 125773it [00:00, 264431.86it/s]

# %%
S.describe()
# Out:
# Nb of Nodes :  242
# Nb of segmented nodes :  242.0
# Nb of links :  8317
# Nb of segmented links :  125773.0
# Nb of event times :  3100

# %%
b = operator.lt
walk_type = "passive"
fun =  mw.Metawalk.co_sfp

# %%
events, events_reverse = bt.events_dic(S)

# %%
exact_between, betweenness ,features = bt.betweenness_all_dis_gen(S, b, fun, walk_type, approx = 1)
# Out:
# 122
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/mehdi/sage_github/sage/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-53a413d70b56>", line 1, in <module>
#     exact_between, betweenness ,features = bt.betweenness_all_dis_gen(S, b, fun, walk_type, approx = 1)
#   File "/home/mehdi/sage_github/sage/lib/python3.9/site-packages/straph/betweenness/betweenness_all.py", line 258, in betweenness_all_dis_gen
#     GG = bt.graph_to_ordered(G, events, events_reverse)
#   File "/home/mehdi/sage_github/sage/lib/python3.9/site-packages/straph/betweenness/predecessor_graph.py", line 135, in graph_to_ordered
# ...

# %%
b = operator.lt
walk_type = "active"

# %%
exact_between2, betweenness2 ,features2 = bt.betweenness_all_dis_gen(S, b, fun, walk_type, approx = -1)

# %%
d = [ S.node_to_label[v]  for v in S.nodes ]

# %% [markdown]
# Let's print a short description of this dataset.

# %%
ax = bt.heatmap_betweenness(S, events, exact_between, d, square = True)
fig = ax.get_figure()
fig.savefig("out.png")

# %%
ax = bt.heatmap_betweenness(S, events, exact_between2, d, square = True)
fig = ax.get_figure()
fig.savefig("out.png")

# %%
from scipy import stats
stats.spearmanr([ exact_between2[v][t]  for t in events for v in exact_between2.keys()], [ exact_between[v][t]  for t in events for v in exact_between.keys()])
# Out:
# SpearmanrResult(correlation=0.6493207497743613, pvalue=4.923559876997522e-54)

# %%
0.7874046073615025
0.5360835483597782
0.6493207497743613

# %%
ax = bt.heatmap_betweenness(S, events, betweenness, d, square = True)
fig = ax.get_figure()
fig.savefig("out.png")

# %%
ax = bt.heatmap_betweenness(S, events, betweenness2, d, square = True)
fig = ax.get_figure()
fig.savefig("out.png")

# %%
from scipy import stats
stats.spearmanr([ betweenness2[v][t]  for t in events for v in betweenness2.keys()], [ betweenness[v][t]  for t in events for v in betweenness.keys()])
# Out:
# SpearmanrResult(correlation=0.825096375664982, pvalue=1.1442444036137878e-110)

# %%
0.825096375664982
0.7305567866440246
0.800197362553802

# %%
ax = bt.heatmap_betweenness(nouveau, events, bet, square = False)
fig = ax.get_figure()
fig.savefig("out.png")

# %%
bt.aggregated_time_betweenness(nouveau, events, bet, square = False)
fig = ax.get_figure()
fig.savefig("out.png")

# %%
ax = bt.aggregated_node_betweenness(nouveau, events, bet, square = False)
fig = ax.get_figure()
fig.savefig("out.png")

# %%
ax = bt.heatmap_betweenness(nouveau, events, bet, square = True)
fig = ax.get_figure()
fig.savefig("out.png")

# %%
SS.write_to_sg("examples/")
