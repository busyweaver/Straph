# %%
pip install ../../
# Out:
# Processing /home/mehdi/Straph
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Building wheels for collected packages: straph
#   Building wheel for straph (setup.py) ... done
#   Created wheel for straph: filename=straph-0.3-py3-none-any.whl size=123433 sha256=2e0f44418f1f4694b1b9627648d1f7d1de993f8e472403ac7b034580d65ec673
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ay7b7ij7/wheels/a5/b6/52/18c617da8ab7981501f28a49d398fa4ccca532d1baece44b1e
# Successfully built straph
# Installing collected packages: straph
#   Attempting uninstall: straph
#     Found existing installation: straph 0.3
#     Uninstalling straph-0.3:
#       Successfully uninstalled straph-0.3
# Successfully installed straph-0.3
# WARNING: You are using pip version 21.2.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/mehdi/sage/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import straph as sg
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (12,9)

# %%
#sigmasv_links.sg
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (25,20)
import straph as sg
import straph.betweenness as bt
path_directory = "examples/"
S = sg.read_stream_graph(path_nodes=path_directory + "latapy_test_intro_nodes.sg",
                      path_links=path_directory + "latapy_test_intro_links.sg")
S.describe()
# Out:
# Nb of Nodes :  5
# Nb of segmented nodes :  5.0
# Nb of links :  12
# Nb of segmented links :  32.0
# Nb of event times :  26

# %%
S.write_to_matthieu_link_stream("ex-intro")

# %%
import straph.betweenness as bt

# %%
betweenness, general_contri, nouveau, events, features = bt.betweenness_all(S)
# Out:
# 0
# ********** (9.0, 11.0) **************
# [(3, 6.0), (3, 7.0), (4, 11.0)]
# ///////////////////////
# (4, 11.0) {} {(4, 11.0)}
# (3, 7.0) {} {(3, 7.0)}
# (4, 11.0) {} {(3, 7.0)}
# (3, 6.0) {} {(3, 6.0)}
# (4, 11.0) {} {(3, 6.0)}
# ********** (6.0, 7.0) **************
# [(2, 3.0), (2, 5.0), (3, 7.0)]
# ///////////////////////
# (3, 7.0) {} {(3, 7.0)}
# (2, 5.0) {} {(2, 5.0)}
# (3, 7.0) {} {(2, 5.0)}
# (2, 3.0) {} {(2, 3.0)}
# (3, 7.0) {} {(2, 3.0)}
# ********** (3.0, 5.0) **************
# [(1, 2.0), (2, 5.0)]
# ///////////////////////
# (2, 5.0) {} {(2, 5.0)}
# (1, 2.0) {} {(1, 2.0)}
# (2, 5.0) {} {(1, 2.0)}
# ********** (18.0, 19.0) **************
# [(2, 19.0), (3, 19.0)]
# ///////////////////////
# (3, 19.0) {} {(3, 19.0)}
# (2, 19.0) {} {(2, 19.0)}
# (3, 19.0) {} {(2, 19.0)}
# ********** (23.0, 24.0) **************
# [(3, 19.0), (4, 24.0)]
# ///////////////////////
# (4, 24.0) {} {(4, 24.0)}
# (3, 19.0) {} {(3, 19.0)}
# (4, 24.0) {} {(3, 19.0)}
# ********** (19.0, 22.0) **************
# [(1, 16.0), (2, 22.0)]
# ///////////////////////
# (2, 22.0) {} {(2, 22.0)}
# (1, 16.0) {} {(1, 16.0)}
# (2, 22.0) {} {(1, 16.0)}
# ********** (30.0, 31.0) **************
# [(3, 27.0), (3, 28.0), (3, 29.0), (4, 31.0)]
# ///////////////////////
# (4, 31.0) {} {(4, 31.0)}
# (3, 29.0) {} {(3, 29.0)}
# (4, 31.0) {} {(3, 29.0)}
# (3, 28.0) {} {(3, 28.0)}
# (4, 31.0) {} {(3, 28.0)}
# (3, 27.0) {} {(3, 27.0)}
# (4, 31.0) {} {(3, 27.0)}
# ********** (27.0, 28.0) **************
# [(2, 25.0), (2, 27.0), (1, 24.0), (2, 28.0), (3, 28.0)]
# ///////////////////////
# (3, 28.0) {} {(3, 28.0)}
# (2, 28.0) {} {(2, 28.0)}
# (3, 28.0) {} {(2, 28.0)}
# (1, 24.0) {} {(1, 24.0)}
# (2, 28.0) {} {(1, 24.0)}
# (2, 27.0) {} {(2, 27.0)}
# (3, 28.0) {} {(2, 27.0)}
# (2, 25.0) {} {(2, 25.0)}
# (3, 28.0) {} {(2, 25.0)}
# ********** (28.0, 29.0) **************
# [(2, 25.0), (2, 27.0), (2, 28.0), (3, 29.0)]
# ///////////////////////
# (3, 29.0) {} {(3, 29.0)}
# (2, 28.0) {} {(2, 28.0)}
# (3, 29.0) {} {(2, 28.0)}
# (2, 27.0) {} {(2, 27.0)}
# (3, 29.0) {} {(2, 27.0)}
# (2, 25.0) {} {(2, 25.0)}
# (3, 29.0) {} {(2, 25.0)}
# ********** (25.0, 27.0) **************
# [(1, 24.0), (2, 27.0)]
# ///////////////////////
# (2, 27.0) {} {(2, 27.0)}
# (1, 24.0) {} {(1, 24.0)}
# (2, 27.0) {} {(1, 24.0)}
# ********** (12.0, 14.0) **************
# [(1, 11.0), (3, 14.0)]
# ///////////////////////
# (3, 14.0) {} {(3, 14.0)}
# (1, 11.0) {} {(1, 11.0)}
# (3, 14.0) {} {(1, 11.0)}
# 0 1 1.0 -1 -1 -1 -1
# edge after 1.0 2.0
# t1p,t2p 1.0 1.0
# 0 1 2.0 -1 -1 -1 -1
# t1p,t2p 1.0 2.0
# 1 2 2.0 1.0 2.0 -2 -1
# edge after 3.0 5.0
# t1p,t2p 3.0 3.0
# 1 2 2.0 1.0 2.0 -2 -1
# t1p,t2p 3.0 5.0
# 0 1 15.0 -1 -1 -1 -1
# edge after 15.0 16.0
# t1p,t2p 15.0 15.0
# 0 1 16.0 -1 -1 -1 -1
# t1p,t2p 15.0 16.0
# 1 2 16.0 15.0 16.0 -2 -1
# edge after 19.0 22.0
# t1p,t2p 19.0 19.0
# 1 2 16.0 15.0 16.0 -2 -1
# t1p,t2p 19.0 22.0
# 0 1 23.0 -1 -1 -1 -1
# edge after 23.0 24.0
# t1p,t2p 23.0 23.0
# 0 1 24.0 -1 -1 -1 -1
# t1p,t2p 23.0 24.0
# 1 2 24.0 23.0 24.0 -2 -1
# edge after 25.0 27.0
# t1p,t2p 25.0 25.0
# 1 2 24.0 23.0 24.0 -2 -1
# edge after 27.0 28.0
# t1p,t2p 25.0 27.0
# 1 2 24.0 23.0 24.0 -2 -1
# t1p,t2p 27.0 28.0
# 0 2 8.0 -1 -1 -1 -1
# edge after 8.0 9.0
# t1p,t2p 8.0 8.0
# 0 2 9.0 -1 -1 -1 -1
# t1p,t2p 8.0 9.0
# 2 1 9.0 8.0 9.0 -2 -1
# t1p,t2p 11.0 11.0
# 2 3 9.0 8.0 9.0 -2 -1
# edge after 18.0 19.0
# t1p,t2p 18.0 18.0
# 1
# ********** (8.0, 9.0) **************
# [(2, 5.0), (0, 9.0)]
# ///////////////////////
# (0, 9.0) {} {(0, 9.0)}
# (2, 5.0) {} {(2, 5.0)}
# (0, 9.0) {} {(2, 5.0)}
# ********** (9.0, 11.0) **************
# [(3, 6.0), (3, 7.0), (4, 11.0)]
# ///////////////////////
# (4, 11.0) {} {(4, 11.0)}
# (3, 7.0) {} {(3, 7.0)}
# (4, 11.0) {} {(3, 7.0)}
# (3, 6.0) {} {(3, 6.0)}
# (4, 11.0) {} {(3, 6.0)}
# ********** (6.0, 7.0) **************
# [(2, 5.0), (3, 7.0)]
# ///////////////////////
# (3, 7.0) {} {(3, 7.0)}
# (2, 5.0) {} {(2, 5.0)}
# (3, 7.0) {} {(2, 5.0)}
# ********** (18.0, 19.0) **************
# [(2, 19.0), (3, 19.0)]
# ///////////////////////
# (3, 19.0) {} {(3, 19.0)}
# (2, 19.0) {} {(2, 19.0)}
# (3, 19.0) {} {(2, 19.0)}
# ********** (23.0, 24.0) **************
# [(3, 19.0), (4, 24.0)]
# ///////////////////////
# (4, 24.0) {} {(4, 24.0)}
# (3, 19.0) {} {(3, 19.0)}
# (4, 24.0) {} {(3, 19.0)}
# ********** (27.0, 28.0) **************
# [(2, 28.0), (3, 28.0)]
# ///////////////////////
# (3, 28.0) {} {(3, 28.0)}
# (2, 28.0) {} {(2, 28.0)}
# (3, 28.0) {} {(2, 28.0)}
# ********** (30.0, 31.0) **************
# [(3, 28.0), (3, 29.0), (4, 31.0)]
# ///////////////////////
# (4, 31.0) {} {(4, 31.0)}
# (3, 29.0) {} {(3, 29.0)}
# (4, 31.0) {} {(3, 29.0)}
# (3, 28.0) {} {(3, 28.0)}
# (4, 31.0) {} {(3, 28.0)}
# ********** (28.0, 29.0) **************
# [(2, 28.0), (3, 29.0)]
# ///////////////////////
# (3, 29.0) {} {(3, 29.0)}
# (2, 28.0) {} {(2, 28.0)}
# (3, 29.0) {} {(2, 28.0)}
# 1 0 1.0 -1 -1 -1 -1
# edge after 1.0 2.0
# t1p,t2p 1.0 1.0
# 1 0 2.0 -1 -1 -1 -1
# t1p,t2p 1.0 2.0
# 1 0 15.0 -1 -1 -1 -1
# edge after 15.0 16.0
# t1p,t2p 15.0 15.0
# 1 0 16.0 -1 -1 -1 -1
# t1p,t2p 15.0 16.0
# 1 0 23.0 -1 -1 -1 -1
# edge after 23.0 24.0
# t1p,t2p 23.0 23.0
# 1 0 24.0 -1 -1 -1 -1
# t1p,t2p 23.0 24.0
# 1 2 3.0 -1 -1 -1 -1
# edge after 3.0 5.0
# t1p,t2p 3.0 3.0
# 1 2 5.0 -1 -1 -1 -1
# t1p,t2p 3.0 5.0
# 2 0 5.0 3.0 5.0 -2 -1
# edge after 8.0 9.0
# t1p,t2p 8.0 8.0
# 2 0 5.0 3.0 5.0 -2 -1
# t1p,t2p 8.0 9.0
# 2 3 5.0 3.0 5.0 -2 -1
# edge after 6.0 7.0
# t1p,t2p 6.0 6.0
# 2 3 5.0 3.0 5.0 -2 -1
# t1p,t2p 6.0 7.0
# 1 2 11.0 -1 -1 -1 -1
# t1p,t2p 11.0 11.0
# 1 2 19.0 -1 -1 -1 -1
# edge after 19.0 22.0
# t1p,t2p 19.0 19.0
# 2 3 19.0 19.0 19.0 19.0 22.0
# t1p,t2p 18.0 19.0
# 1 2 22.0 -1 -1 -1 -1
# t1p,t2p 19.0 22.0
# 1 2 25.0 -1 -1 -1 -1
# edge after 25.0 27.0
# t1p,t2p 25.0 25.0
# 1 2 27.0 -1 -1 -1 -1
# edge after 27.0 28.0
# t1p,t2p 25.0 27.0
# 2 3 27.0 25.0 27.0 27.0 28.0
# edge after 27.0 28.0
# t1p,t2p 27.0 27.0
# 2 3 27.0 25.0 27.0 27.0 28.0
# edge after 27.0 28.0
# t1p,t2p 27.0 27.0
# 1 2 28.0 -1 -1 -1 -1
# t1p,t2p 27.0 28.0
# 2 3 28.0 27.0 28.0 -2 -1
# edge after 28.0 29.0
# t1p,t2p 27.0 28.0
# 3 4 28.0 27.0 28.0 -2 -1
# edge after 30.0 31.0
# t1p,t2p 30.0 30.0
# 3 4 28.0 27.0 28.0 -2 -1
# t1p,t2p 30.0 31.0
# 2 3 28.0 27.0 28.0 -2 -1
# t1p,t2p 28.0 29.0
# 1 3 12.0 -1 -1 -1 -1
# edge after 12.0 14.0
# t1p,t2p 12.0 12.0
# 1 3 14.0 -1 -1 -1 -1
# t1p,t2p 12.0 14.0
# 3 2 14.0 12.0 14.0 -2 -1
# edge after 18.0 19.0
# t1p,t2p 18.0 18.0
# 3 4 14.0 12.0 14.0 -2 -1
# t1p,t2p 16.0 16.0
# 2
# ********** (15.0, 16.0) **************
# [(1, 11.0), (0, 16.0)]
# ///////////////////////
# (0, 16.0) {} {(0, 16.0)}
# (1, 11.0) {} {(1, 11.0)}
# (0, 16.0) {} {(1, 11.0)}
# ********** (12.0, 14.0) **************
# [(1, 11.0), (3, 14.0)]
# ///////////////////////
# (3, 14.0) {} {(3, 14.0)}
# (1, 11.0) {} {(1, 11.0)}
# (3, 14.0) {} {(1, 11.0)}
# ********** (23.0, 24.0) **************
# [(3, 19.0), (1, 22.0), (4, 24.0), (0, 24.0)]
# ///////////////////////
# (0, 24.0) {} {(0, 24.0)}
# (4, 24.0) {} {(4, 24.0)}
# (1, 22.0) {} {(1, 22.0)}
# (0, 24.0) {} {(1, 22.0)}
# (3, 19.0) {} {(3, 19.0)}
# (4, 24.0) {} {(3, 19.0)}
# ********** (9.0, 11.0) **************
# [(3, 7.0), (4, 11.0)]
# ///////////////////////
# (4, 11.0) {} {(4, 11.0)}
# (3, 7.0) {} {(3, 7.0)}
# (4, 11.0) {} {(3, 7.0)}
# ********** (30.0, 31.0) **************
# [(3, 29.0), (4, 31.0)]
# ///////////////////////
# (4, 31.0) {} {(4, 31.0)}
# (3, 29.0) {} {(3, 29.0)}
# (4, 31.0) {} {(3, 29.0)}
# 2 0 8.0 -1 -1 -1 -1
# edge after 8.0 9.0
# t1p,t2p 8.0 8.0
# 2 0 9.0 -1 -1 -1 -1
# t1p,t2p 8.0 9.0
# 2 1 3.0 -1 -1 -1 -1
# edge after 3.0 5.0
# t1p,t2p 3.0 3.0
# 2 1 5.0 -1 -1 -1 -1
# t1p,t2p 3.0 5.0
# 2 1 11.0 -1 -1 -1 -1
# t1p,t2p 11.0 11.0
# 2 1 19.0 -1 -1 -1 -1
# edge after 19.0 22.0
# t1p,t2p 19.0 19.0
# 2 3 19.0 19.0 19.0 19.0 22.0
# t1p,t2p 18.0 19.0
# 2 1 22.0 -1 -1 -1 -1
# t1p,t2p 19.0 22.0
# 1 0 22.0 19.0 22.0 -2 -1
# edge after 23.0 24.0
# t1p,t2p 23.0 23.0
# 1 0 22.0 19.0 22.0 -2 -1
# t1p,t2p 23.0 24.0
# 2 1 25.0 -1 -1 -1 -1
# edge after 25.0 27.0
# t1p,t2p 25.0 25.0
# 2 1 27.0 -1 -1 -1 -1
# edge after 27.0 28.0
# t1p,t2p 25.0 27.0
# 2 3 27.0 25.0 27.0 27.0 28.0
# edge after 27.0 28.0
# t1p,t2p 27.0 27.0
# 2 1 28.0 -1 -1 -1 -1
# t1p,t2p 27.0 28.0
# 2 3 28.0 27.0 28.0 -2 -1
# edge after 28.0 29.0
# t1p,t2p 27.0 28.0
# 2 3 6.0 -1 -1 -1 -1
# edge after 6.0 7.0
# t1p,t2p 6.0 6.0
# 2 3 7.0 -1 -1 -1 -1
# t1p,t2p 6.0 7.0
# 3 4 7.0 6.0 7.0 -2 -1
# edge after 9.0 11.0
# t1p,t2p 9.0 9.0
# 3 4 7.0 6.0 7.0 -2 -1
# t1p,t2p 9.0 11.0
# 2 3 18.0 -1 -1 -1 -1
# edge after 18.0 19.0
# t1p,t2p 18.0 18.0
# 2 3 29.0 -1 -1 -1 -1
# t1p,t2p 28.0 29.0
# 3 4 29.0 28.0 29.0 -2 -1
# edge after 30.0 31.0
# t1p,t2p 30.0 30.0
# 3 4 29.0 28.0 29.0 -2 -1
# t1p,t2p 30.0 31.0
# 3
# ********** (15.0, 16.0) **************
# [(1, 14.0), (0, 16.0)]
# ///////////////////////
# (0, 16.0) {} {(0, 16.0)}
# (1, 14.0) {} {(1, 14.0)}
# (0, 16.0) {} {(1, 14.0)}
# ********** (8.0, 9.0) **************
# [(2, 7.0), (0, 9.0)]
# ///////////////////////
# (0, 9.0) {} {(0, 9.0)}
# (2, 7.0) {} {(2, 7.0)}
# (0, 9.0) {} {(2, 7.0)}
# ********** (23.0, 24.0) **************
# [(1, 19.0), (1, 22.0), (0, 24.0)]
# ///////////////////////
# (0, 24.0) {} {(0, 24.0)}
# (1, 22.0) {} {(1, 22.0)}
# (0, 24.0) {} {(1, 22.0)}
# (1, 19.0) {} {(1, 19.0)}
# (0, 24.0) {} {(1, 19.0)}
# ********** (19.0, 22.0) **************
# [(2, 19.0), (1, 22.0)]
# ///////////////////////
# (1, 22.0) {} {(1, 22.0)}
# (2, 19.0) {} {(2, 19.0)}
# (1, 22.0) {} {(2, 19.0)}
# ********** (25.0, 27.0) **************
# [(2, 27.0), (1, 27.0)]
# ///////////////////////
# (1, 27.0) {} {(1, 27.0)}
# (2, 27.0) {} {(2, 27.0)}
# (1, 27.0) {} {(2, 27.0)}
# ********** (27.0, 28.0) **************
# [(2, 28.0), (1, 28.0)]
# ///////////////////////
# (1, 28.0) {} {(1, 28.0)}
# (2, 28.0) {} {(2, 28.0)}
# (1, 28.0) {} {(2, 28.0)}
# 3 1 12.0 -1 -1 -1 -1
# edge after 12.0 14.0
# t1p,t2p 12.0 12.0
# 3 1 14.0 -1 -1 -1 -1
# t1p,t2p 12.0 14.0
# 1 0 14.0 12.0 14.0 -2 -1
# edge after 15.0 16.0
# t1p,t2p 15.0 15.0
# 1 0 14.0 12.0 14.0 -2 -1
# t1p,t2p 15.0 16.0
# 3 2 6.0 -1 -1 -1 -1
# edge after 6.0 7.0
# t1p,t2p 6.0 6.0
# 3 2 7.0 -1 -1 -1 -1
# t1p,t2p 6.0 7.0
# 2 0 7.0 6.0 7.0 -2 -1
# edge after 8.0 9.0
# t1p,t2p 8.0 8.0
# 2 0 7.0 6.0 7.0 -2 -1
# t1p,t2p 8.0 9.0
# 2 1 7.0 6.0 7.0 -2 -1
# t1p,t2p 11.0 11.0
# 3 2 18.0 -1 -1 -1 -1
# edge after 18.0 19.0
# t1p,t2p 18.0 18.0
# 3 2 19.0 -1 -1 -1 -1
# t1p,t2p 18.0 19.0
# 2 1 19.0 18.0 19.0 -2 -1
# edge after 19.0 22.0
# t1p,t2p 19.0 19.0
# 2 1 19.0 18.0 19.0 -2 -1
# t1p,t2p 19.0 22.0
# 2 1 19.0 18.0 19.0 -2 -1
# edge after 25.0 27.0
# t1p,t2p 25.0 25.0
# 3 2 27.0 -1 -1 -1 -1
# edge after 27.0 28.0
# t1p,t2p 27.0 27.0
# 2 1 27.0 27.0 27.0 27.0 28.0
# edge after 27.0 28.0
# t1p,t2p 25.0 27.0
# 3 2 28.0 -1 -1 -1 -1
# edge after 28.0 29.0
# t1p,t2p 27.0 28.0
# 2 1 28.0 27.0 28.0 28.0 29.0
# t1p,t2p 27.0 28.0
# 2 1 28.0 27.0 28.0 28.0 29.0
# t1p,t2p 27.0 28.0
# 3 2 29.0 -1 -1 -1 -1
# t1p,t2p 28.0 29.0
# 3 4 9.0 -1 -1 -1 -1
# edge after 9.0 11.0
# t1p,t2p 9.0 9.0
# 3 4 11.0 -1 -1 -1 -1
# t1p,t2p 9.0 11.0
# 3 4 16.0 -1 -1 -1 -1
# t1p,t2p 16.0 16.0
# 3 4 23.0 -1 -1 -1 -1
# edge after 23.0 24.0
# t1p,t2p 23.0 23.0
# 3 4 24.0 -1 -1 -1 -1
# t1p,t2p 23.0 24.0
# 3 4 30.0 -1 -1 -1 -1
# edge after 30.0 31.0
# t1p,t2p 30.0 30.0
# 3 4 31.0 -1 -1 -1 -1
# t1p,t2p 30.0 31.0
# 4
# ********** (15.0, 16.0) **************
# [(1, 12.0), (1, 14.0), (0, 16.0)]
# ///////////////////////
# (0, 16.0) {} {(0, 16.0)}
# (1, 14.0) {} {(1, 14.0)}
# (0, 16.0) {} {(1, 14.0)}
# (1, 12.0) {} {(1, 12.0)}
# (0, 16.0) {} {(1, 12.0)}
# ********** (12.0, 14.0) **************
# [(3, 11.0), (1, 14.0)]
# ///////////////////////
# (1, 14.0) {} {(1, 14.0)}
# (3, 11.0) {} {(3, 11.0)}
# (1, 14.0) {} {(3, 11.0)}
# ********** (23.0, 24.0) **************
# [(1, 19.0), (1, 22.0), (0, 24.0)]
# ///////////////////////
# (0, 24.0) {} {(0, 24.0)}
# (1, 22.0) {} {(1, 22.0)}
# (0, 24.0) {} {(1, 22.0)}
# (1, 19.0) {} {(1, 19.0)}
# (0, 24.0) {} {(1, 19.0)}
# ********** (19.0, 22.0) **************
# [(2, 18.0), (2, 19.0), (1, 22.0)]
# ///////////////////////
# (1, 22.0) {} {(1, 22.0)}
# (2, 19.0) {} {(2, 19.0)}
# (1, 22.0) {} {(2, 19.0)}
# (2, 18.0) {} {(2, 18.0)}
# (1, 22.0) {} {(2, 18.0)}
# ********** (18.0, 19.0) **************
# [(3, 16.0), (2, 19.0)]
# ///////////////////////
# (2, 19.0) {} {(2, 19.0)}
# (3, 16.0) {} {(3, 16.0)}
# (2, 19.0) {} {(3, 16.0)}
# ********** (25.0, 27.0) **************
# [(2, 27.0), (1, 27.0)]
# ///////////////////////
# (1, 27.0) {} {(1, 27.0)}
# (2, 27.0) {} {(2, 27.0)}
# (1, 27.0) {} {(2, 27.0)}
# ********** (27.0, 28.0) **************
# [(2, 27.0), (3, 24.0), (2, 28.0), (1, 28.0)]
# ///////////////////////
# (1, 28.0) {} {(1, 28.0)}
# (2, 28.0) {} {(2, 28.0)}
# (1, 28.0) {} {(2, 28.0)}
# (3, 24.0) {} {(3, 24.0)}
# (2, 28.0) {} {(3, 24.0)}
# (2, 27.0) {} {(2, 27.0)}
# (1, 28.0) {} {(2, 27.0)}
# ********** (28.0, 29.0) **************
# [(3, 24.0), (2, 29.0)]
# ///////////////////////
# (2, 29.0) {} {(2, 29.0)}
# (3, 24.0) {} {(3, 24.0)}
# (2, 29.0) {} {(3, 24.0)}
# 4 3 9.0 -1 -1 -1 -1
# edge after 9.0 11.0
# t1p,t2p 9.0 9.0
# 4 3 11.0 -1 -1 -1 -1
# t1p,t2p 9.0 11.0
# 3 1 11.0 9.0 11.0 -2 -1
# edge after 12.0 14.0
# t1p,t2p 12.0 12.0
# 3 1 11.0 9.0 11.0 -2 -1
# t1p,t2p 12.0 14.0
# 4 3 16.0 -1 -1 -1 -1
# t1p,t2p 16.0 16.0
# 4 3 23.0 -1 -1 -1 -1
# edge after 23.0 24.0
# t1p,t2p 23.0 23.0
# 4 3 24.0 -1 -1 -1 -1
# t1p,t2p 23.0 24.0
# 3 2 24.0 23.0 24.0 -2 -1
# edge after 27.0 28.0
# t1p,t2p 27.0 27.0
# 3 2 24.0 23.0 24.0 -2 -1
# edge after 28.0 29.0
# t1p,t2p 27.0 28.0
# 3 2 24.0 23.0 24.0 -2 -1
# t1p,t2p 28.0 29.0
# 4 3 30.0 -1 -1 -1 -1
# edge after 30.0 31.0
# t1p,t2p 30.0 30.0
# 4 3 31.0 -1 -1 -1 -1
# t1p,t2p 30.0 31.0

# %%
bt.simulations(S, "papier")
# Out:
# 0
# ********** (9.0, 11.0) **************
# [(3, 6.0), (3, 7.0), (4, 11.0)]
# ///////////////////////
# (4, 11.0) {} {(4, 11.0)}
# (3, 7.0) {} {(3, 7.0)}
# (4, 11.0) {} {(3, 7.0)}
# (3, 6.0) {} {(3, 6.0)}
# (4, 11.0) {} {(3, 6.0)}
# ********** (6.0, 7.0) **************
# [(2, 3.0), (2, 5.0), (3, 7.0)]
# ///////////////////////
# (3, 7.0) {} {(3, 7.0)}
# (2, 5.0) {} {(2, 5.0)}
# (3, 7.0) {} {(2, 5.0)}
# (2, 3.0) {} {(2, 3.0)}
# (3, 7.0) {} {(2, 3.0)}
# ********** (3.0, 5.0) **************
# [(1, 2.0), (2, 5.0)]
# ///////////////////////
# (2, 5.0) {} {(2, 5.0)}
# (1, 2.0) {} {(1, 2.0)}
# (2, 5.0) {} {(1, 2.0)}
# ********** (18.0, 19.0) **************
# [(2, 19.0), (3, 19.0)]
# ///////////////////////
# (3, 19.0) {} {(3, 19.0)}
# (2, 19.0) {} {(2, 19.0)}
# (3, 19.0) {} {(2, 19.0)}
# ********** (23.0, 24.0) **************
# [(3, 19.0), (4, 24.0)]
# ///////////////////////
# (4, 24.0) {} {(4, 24.0)}
# (3, 19.0) {} {(3, 19.0)}
# (4, 24.0) {} {(3, 19.0)}
# ********** (19.0, 22.0) **************
# [(1, 16.0), (2, 22.0)]
# ///////////////////////
# (2, 22.0) {} {(2, 22.0)}
# (1, 16.0) {} {(1, 16.0)}
# (2, 22.0) {} {(1, 16.0)}
# ********** (30.0, 31.0) **************
# [(3, 27.0), (3, 28.0), (3, 29.0), (4, 31.0)]
# ///////////////////////
# (4, 31.0) {} {(4, 31.0)}
# (3, 29.0) {} {(3, 29.0)}
# (4, 31.0) {} {(3, 29.0)}
# (3, 28.0) {} {(3, 28.0)}
# (4, 31.0) {} {(3, 28.0)}
# (3, 27.0) {} {(3, 27.0)}
# (4, 31.0) {} {(3, 27.0)}
# ********** (27.0, 28.0) **************
# [(2, 25.0), (2, 27.0), (1, 24.0), (2, 28.0), (3, 28.0)]
# ///////////////////////
# (3, 28.0) {} {(3, 28.0)}
# (2, 28.0) {} {(2, 28.0)}
# (3, 28.0) {} {(2, 28.0)}
# (1, 24.0) {} {(1, 24.0)}
# (2, 28.0) {} {(1, 24.0)}
# (2, 27.0) {} {(2, 27.0)}
# (3, 28.0) {} {(2, 27.0)}
# (2, 25.0) {} {(2, 25.0)}
# (3, 28.0) {} {(2, 25.0)}
# ********** (28.0, 29.0) **************
# [(2, 25.0), (2, 27.0), (2, 28.0), (3, 29.0)]
# ///////////////////////
# (3, 29.0) {} {(3, 29.0)}
# (2, 28.0) {} {(2, 28.0)}
# (3, 29.0) {} {(2, 28.0)}
# (2, 27.0) {} {(2, 27.0)}
# (3, 29.0) {} {(2, 27.0)}
# (2, 25.0) {} {(2, 25.0)}
# (3, 29.0) {} {(2, 25.0)}
# ********** (25.0, 27.0) **************
# [(1, 24.0), (2, 27.0)]
# ///////////////////////
# (2, 27.0) {} {(2, 27.0)}
# (1, 24.0) {} {(1, 24.0)}
# (2, 27.0) {} {(1, 24.0)}
# ********** (12.0, 14.0) **************
# [(1, 11.0), (3, 14.0)]
# ///////////////////////
# (3, 14.0) {} {(3, 14.0)}
# (1, 11.0) {} {(1, 11.0)}
# (3, 14.0) {} {(1, 11.0)}
# 0 1 1.0 -1 -1 -1 -1
# edge after 1.0 2.0
# t1p,t2p 1.0 1.0
# 0 1 2.0 -1 -1 -1 -1
# t1p,t2p 1.0 2.0
# 1 2 2.0 1.0 2.0 -2 -1
# edge after 3.0 5.0
# t1p,t2p 3.0 3.0
# 1 2 2.0 1.0 2.0 -2 -1
# t1p,t2p 3.0 5.0
# 0 1 15.0 -1 -1 -1 -1
# edge after 15.0 16.0
# t1p,t2p 15.0 15.0
# 0 1 16.0 -1 -1 -1 -1
# t1p,t2p 15.0 16.0
# 1 2 16.0 15.0 16.0 -2 -1
# edge after 19.0 22.0
# t1p,t2p 19.0 19.0
# 1 2 16.0 15.0 16.0 -2 -1
# t1p,t2p 19.0 22.0
# 0 1 23.0 -1 -1 -1 -1
# edge after 23.0 24.0
# t1p,t2p 23.0 23.0
# 0 1 24.0 -1 -1 -1 -1
# t1p,t2p 23.0 24.0
# 1 2 24.0 23.0 24.0 -2 -1
# edge after 25.0 27.0
# t1p,t2p 25.0 25.0
# 1 2 24.0 23.0 24.0 -2 -1
# edge after 27.0 28.0
# t1p,t2p 25.0 27.0
# 1 2 24.0 23.0 24.0 -2 -1
# t1p,t2p 27.0 28.0
# 0 2 8.0 -1 -1 -1 -1
# edge after 8.0 9.0
# t1p,t2p 8.0 8.0
# 0 2 9.0 -1 -1 -1 -1
# t1p,t2p 8.0 9.0
# 2 1 9.0 8.0 9.0 -2 -1
# t1p,t2p 11.0 11.0
# 2 3 9.0 8.0 9.0 -2 -1
# edge after 18.0 19.0
# t1p,t2p 18.0 18.0
# 1
# ********** (8.0, 9.0) **************
# [(2, 5.0), (0, 9.0)]
# ///////////////////////
# (0, 9.0) {} {(0, 9.0)}
# (2, 5.0) {} {(2, 5.0)}
# (0, 9.0) {} {(2, 5.0)}
# ********** (9.0, 11.0) **************
# [(3, 6.0), (3, 7.0), (4, 11.0)]
# ///////////////////////
# (4, 11.0) {} {(4, 11.0)}
# (3, 7.0) {} {(3, 7.0)}
# (4, 11.0) {} {(3, 7.0)}
# (3, 6.0) {} {(3, 6.0)}
# (4, 11.0) {} {(3, 6.0)}
# ********** (6.0, 7.0) **************
# [(2, 5.0), (3, 7.0)]
# ///////////////////////
# (3, 7.0) {} {(3, 7.0)}
# (2, 5.0) {} {(2, 5.0)}
# (3, 7.0) {} {(2, 5.0)}
# ********** (18.0, 19.0) **************
# [(2, 19.0), (3, 19.0)]
# ///////////////////////
# (3, 19.0) {} {(3, 19.0)}
# (2, 19.0) {} {(2, 19.0)}
# (3, 19.0) {} {(2, 19.0)}
# ********** (23.0, 24.0) **************
# [(3, 19.0), (4, 24.0)]
# ///////////////////////
# (4, 24.0) {} {(4, 24.0)}
# (3, 19.0) {} {(3, 19.0)}
# (4, 24.0) {} {(3, 19.0)}
# ********** (27.0, 28.0) **************
# [(2, 28.0), (3, 28.0)]
# ///////////////////////
# (3, 28.0) {} {(3, 28.0)}
# (2, 28.0) {} {(2, 28.0)}
# (3, 28.0) {} {(2, 28.0)}
# ********** (30.0, 31.0) **************
# [(3, 28.0), (3, 29.0), (4, 31.0)]
# ///////////////////////
# (4, 31.0) {} {(4, 31.0)}
# (3, 29.0) {} {(3, 29.0)}
# (4, 31.0) {} {(3, 29.0)}
# (3, 28.0) {} {(3, 28.0)}
# (4, 31.0) {} {(3, 28.0)}
# ********** (28.0, 29.0) **************
# [(2, 28.0), (3, 29.0)]
# ///////////////////////
# (3, 29.0) {} {(3, 29.0)}
# (2, 28.0) {} {(2, 28.0)}
# (3, 29.0) {} {(2, 28.0)}
# 1 0 1.0 -1 -1 -1 -1
# edge after 1.0 2.0
# t1p,t2p 1.0 1.0
# 1 0 2.0 -1 -1 -1 -1
# t1p,t2p 1.0 2.0
# 1 0 15.0 -1 -1 -1 -1
# edge after 15.0 16.0
# t1p,t2p 15.0 15.0
# 1 0 16.0 -1 -1 -1 -1
# t1p,t2p 15.0 16.0
# 1 0 23.0 -1 -1 -1 -1
# edge after 23.0 24.0
# t1p,t2p 23.0 23.0
# 1 0 24.0 -1 -1 -1 -1
# t1p,t2p 23.0 24.0
# 1 2 3.0 -1 -1 -1 -1
# edge after 3.0 5.0
# t1p,t2p 3.0 3.0
# 1 2 5.0 -1 -1 -1 -1
# t1p,t2p 3.0 5.0
# 2 0 5.0 3.0 5.0 -2 -1
# edge after 8.0 9.0
# t1p,t2p 8.0 8.0
# 2 0 5.0 3.0 5.0 -2 -1
# t1p,t2p 8.0 9.0
# 2 3 5.0 3.0 5.0 -2 -1
# edge after 6.0 7.0
# t1p,t2p 6.0 6.0
# 2 3 5.0 3.0 5.0 -2 -1
# t1p,t2p 6.0 7.0
# 1 2 11.0 -1 -1 -1 -1
# t1p,t2p 11.0 11.0
# 1 2 19.0 -1 -1 -1 -1
# edge after 19.0 22.0
# t1p,t2p 19.0 19.0
# 2 3 19.0 19.0 19.0 19.0 22.0
# t1p,t2p 18.0 19.0
# 1 2 22.0 -1 -1 -1 -1
# t1p,t2p 19.0 22.0
# 1 2 25.0 -1 -1 -1 -1
# edge after 25.0 27.0
# t1p,t2p 25.0 25.0
# 1 2 27.0 -1 -1 -1 -1
# edge after 27.0 28.0
# t1p,t2p 25.0 27.0
# 2 3 27.0 25.0 27.0 27.0 28.0
# edge after 27.0 28.0
# t1p,t2p 27.0 27.0
# 2 3 27.0 25.0 27.0 27.0 28.0
# edge after 27.0 28.0
# t1p,t2p 27.0 27.0
# 1 2 28.0 -1 -1 -1 -1
# t1p,t2p 27.0 28.0
# 2 3 28.0 27.0 28.0 -2 -1
# edge after 28.0 29.0
# t1p,t2p 27.0 28.0
# 3 4 28.0 27.0 28.0 -2 -1
# edge after 30.0 31.0
# t1p,t2p 30.0 30.0
# 3 4 28.0 27.0 28.0 -2 -1
# t1p,t2p 30.0 31.0
# 2 3 28.0 27.0 28.0 -2 -1
# t1p,t2p 28.0 29.0
# 1 3 12.0 -1 -1 -1 -1
# edge after 12.0 14.0
# t1p,t2p 12.0 12.0
# 1 3 14.0 -1 -1 -1 -1
# t1p,t2p 12.0 14.0
# 3 2 14.0 12.0 14.0 -2 -1
# edge after 18.0 19.0
# t1p,t2p 18.0 18.0
# 3 4 14.0 12.0 14.0 -2 -1
# t1p,t2p 16.0 16.0
# 2
# ********** (15.0, 16.0) **************
# [(1, 11.0), (0, 16.0)]
# ///////////////////////
# (0, 16.0) {} {(0, 16.0)}
# (1, 11.0) {} {(1, 11.0)}
# (0, 16.0) {} {(1, 11.0)}
# ********** (12.0, 14.0) **************
# [(1, 11.0), (3, 14.0)]
# ///////////////////////
# (3, 14.0) {} {(3, 14.0)}
# (1, 11.0) {} {(1, 11.0)}
# (3, 14.0) {} {(1, 11.0)}
# ********** (23.0, 24.0) **************
# [(3, 19.0), (1, 22.0), (4, 24.0), (0, 24.0)]
# ///////////////////////
# (0, 24.0) {} {(0, 24.0)}
# (4, 24.0) {} {(4, 24.0)}
# (1, 22.0) {} {(1, 22.0)}
# (0, 24.0) {} {(1, 22.0)}
# (3, 19.0) {} {(3, 19.0)}
# (4, 24.0) {} {(3, 19.0)}
# ********** (9.0, 11.0) **************
# [(3, 7.0), (4, 11.0)]
# ///////////////////////
# (4, 11.0) {} {(4, 11.0)}
# (3, 7.0) {} {(3, 7.0)}
# (4, 11.0) {} {(3, 7.0)}
# ********** (30.0, 31.0) **************
# [(3, 29.0), (4, 31.0)]
# ///////////////////////
# (4, 31.0) {} {(4, 31.0)}
# (3, 29.0) {} {(3, 29.0)}
# (4, 31.0) {} {(3, 29.0)}
# 2 0 8.0 -1 -1 -1 -1
# edge after 8.0 9.0
# t1p,t2p 8.0 8.0
# 2 0 9.0 -1 -1 -1 -1
# t1p,t2p 8.0 9.0
# 2 1 3.0 -1 -1 -1 -1
# edge after 3.0 5.0
# t1p,t2p 3.0 3.0
# 2 1 5.0 -1 -1 -1 -1
# t1p,t2p 3.0 5.0
# 2 1 11.0 -1 -1 -1 -1
# t1p,t2p 11.0 11.0
# 2 1 19.0 -1 -1 -1 -1
# edge after 19.0 22.0
# t1p,t2p 19.0 19.0
# 2 3 19.0 19.0 19.0 19.0 22.0
# t1p,t2p 18.0 19.0
# 2 1 22.0 -1 -1 -1 -1
# t1p,t2p 19.0 22.0
# 1 0 22.0 19.0 22.0 -2 -1
# edge after 23.0 24.0
# t1p,t2p 23.0 23.0
# 1 0 22.0 19.0 22.0 -2 -1
# t1p,t2p 23.0 24.0
# 2 1 25.0 -1 -1 -1 -1
# edge after 25.0 27.0
# t1p,t2p 25.0 25.0
# 2 1 27.0 -1 -1 -1 -1
# edge after 27.0 28.0
# t1p,t2p 25.0 27.0
# 2 3 27.0 25.0 27.0 27.0 28.0
# edge after 27.0 28.0
# t1p,t2p 27.0 27.0
# 2 1 28.0 -1 -1 -1 -1
# t1p,t2p 27.0 28.0
# 2 3 28.0 27.0 28.0 -2 -1
# edge after 28.0 29.0
# t1p,t2p 27.0 28.0
# 2 3 6.0 -1 -1 -1 -1
# edge after 6.0 7.0
# t1p,t2p 6.0 6.0
# 2 3 7.0 -1 -1 -1 -1
# t1p,t2p 6.0 7.0
# 3 4 7.0 6.0 7.0 -2 -1
# edge after 9.0 11.0
# t1p,t2p 9.0 9.0
# 3 4 7.0 6.0 7.0 -2 -1
# t1p,t2p 9.0 11.0
# 2 3 18.0 -1 -1 -1 -1
# edge after 18.0 19.0
# t1p,t2p 18.0 18.0
# 2 3 29.0 -1 -1 -1 -1
# t1p,t2p 28.0 29.0
# 3 4 29.0 28.0 29.0 -2 -1
# edge after 30.0 31.0
# t1p,t2p 30.0 30.0
# 3 4 29.0 28.0 29.0 -2 -1
# t1p,t2p 30.0 31.0
# 3
# ********** (15.0, 16.0) **************
# [(1, 14.0), (0, 16.0)]
# ///////////////////////
# (0, 16.0) {} {(0, 16.0)}
# (1, 14.0) {} {(1, 14.0)}
# (0, 16.0) {} {(1, 14.0)}
# ********** (8.0, 9.0) **************
# [(2, 7.0), (0, 9.0)]
# ///////////////////////
# (0, 9.0) {} {(0, 9.0)}
# (2, 7.0) {} {(2, 7.0)}
# (0, 9.0) {} {(2, 7.0)}
# ********** (23.0, 24.0) **************
# [(1, 19.0), (1, 22.0), (0, 24.0)]
# ///////////////////////
# (0, 24.0) {} {(0, 24.0)}
# (1, 22.0) {} {(1, 22.0)}
# (0, 24.0) {} {(1, 22.0)}
# (1, 19.0) {} {(1, 19.0)}
# (0, 24.0) {} {(1, 19.0)}
# ********** (19.0, 22.0) **************
# [(2, 19.0), (1, 22.0)]
# ///////////////////////
# (1, 22.0) {} {(1, 22.0)}
# (2, 19.0) {} {(2, 19.0)}
# (1, 22.0) {} {(2, 19.0)}
# ********** (25.0, 27.0) **************
# [(2, 27.0), (1, 27.0)]
# ///////////////////////
# (1, 27.0) {} {(1, 27.0)}
# (2, 27.0) {} {(2, 27.0)}
# (1, 27.0) {} {(2, 27.0)}
# ********** (27.0, 28.0) **************
# [(2, 28.0), (1, 28.0)]
# ///////////////////////
# (1, 28.0) {} {(1, 28.0)}
# (2, 28.0) {} {(2, 28.0)}
# (1, 28.0) {} {(2, 28.0)}
# 3 1 12.0 -1 -1 -1 -1
# edge after 12.0 14.0
# t1p,t2p 12.0 12.0
# 3 1 14.0 -1 -1 -1 -1
# t1p,t2p 12.0 14.0
# 1 0 14.0 12.0 14.0 -2 -1
# edge after 15.0 16.0
# t1p,t2p 15.0 15.0
# 1 0 14.0 12.0 14.0 -2 -1
# t1p,t2p 15.0 16.0
# 3 2 6.0 -1 -1 -1 -1
# edge after 6.0 7.0
# t1p,t2p 6.0 6.0
# 3 2 7.0 -1 -1 -1 -1
# t1p,t2p 6.0 7.0
# 2 0 7.0 6.0 7.0 -2 -1
# edge after 8.0 9.0
# t1p,t2p 8.0 8.0
# 2 0 7.0 6.0 7.0 -2 -1
# t1p,t2p 8.0 9.0
# 2 1 7.0 6.0 7.0 -2 -1
# t1p,t2p 11.0 11.0
# 3 2 18.0 -1 -1 -1 -1
# edge after 18.0 19.0
# t1p,t2p 18.0 18.0
# 3 2 19.0 -1 -1 -1 -1
# t1p,t2p 18.0 19.0
# 2 1 19.0 18.0 19.0 -2 -1
# edge after 19.0 22.0
# t1p,t2p 19.0 19.0
# 2 1 19.0 18.0 19.0 -2 -1
# t1p,t2p 19.0 22.0
# 2 1 19.0 18.0 19.0 -2 -1
# edge after 25.0 27.0
# t1p,t2p 25.0 25.0
# 3 2 27.0 -1 -1 -1 -1
# edge after 27.0 28.0
# t1p,t2p 27.0 27.0
# 2 1 27.0 27.0 27.0 27.0 28.0
# edge after 27.0 28.0
# t1p,t2p 25.0 27.0
# 3 2 28.0 -1 -1 -1 -1
# edge after 28.0 29.0
# t1p,t2p 27.0 28.0
# 2 1 28.0 27.0 28.0 28.0 29.0
# t1p,t2p 27.0 28.0
# 2 1 28.0 27.0 28.0 28.0 29.0
# t1p,t2p 27.0 28.0
# 3 2 29.0 -1 -1 -1 -1
# t1p,t2p 28.0 29.0
# 3 4 9.0 -1 -1 -1 -1
# edge after 9.0 11.0
# t1p,t2p 9.0 9.0
# 3 4 11.0 -1 -1 -1 -1
# t1p,t2p 9.0 11.0
# 3 4 16.0 -1 -1 -1 -1
# t1p,t2p 16.0 16.0
# 3 4 23.0 -1 -1 -1 -1
# edge after 23.0 24.0
# t1p,t2p 23.0 23.0
# 3 4 24.0 -1 -1 -1 -1
# t1p,t2p 23.0 24.0
# 3 4 30.0 -1 -1 -1 -1
# edge after 30.0 31.0
# t1p,t2p 30.0 30.0
# 3 4 31.0 -1 -1 -1 -1
# t1p,t2p 30.0 31.0
# 4
# ********** (15.0, 16.0) **************
# [(1, 12.0), (1, 14.0), (0, 16.0)]
# ///////////////////////
# (0, 16.0) {} {(0, 16.0)}
# (1, 14.0) {} {(1, 14.0)}
# (0, 16.0) {} {(1, 14.0)}
# (1, 12.0) {} {(1, 12.0)}
# (0, 16.0) {} {(1, 12.0)}
# ********** (12.0, 14.0) **************
# [(3, 11.0), (1, 14.0)]
# ///////////////////////
# (1, 14.0) {} {(1, 14.0)}
# (3, 11.0) {} {(3, 11.0)}
# (1, 14.0) {} {(3, 11.0)}
# ********** (23.0, 24.0) **************
# [(1, 19.0), (1, 22.0), (0, 24.0)]
# ///////////////////////
# (0, 24.0) {} {(0, 24.0)}
# (1, 22.0) {} {(1, 22.0)}
# (0, 24.0) {} {(1, 22.0)}
# (1, 19.0) {} {(1, 19.0)}
# (0, 24.0) {} {(1, 19.0)}
# ********** (19.0, 22.0) **************
# [(2, 18.0), (2, 19.0), (1, 22.0)]
# ///////////////////////
# (1, 22.0) {} {(1, 22.0)}
# (2, 19.0) {} {(2, 19.0)}
# (1, 22.0) {} {(2, 19.0)}
# (2, 18.0) {} {(2, 18.0)}
# (1, 22.0) {} {(2, 18.0)}
# ********** (18.0, 19.0) **************
# [(3, 16.0), (2, 19.0)]
# ///////////////////////
# (2, 19.0) {} {(2, 19.0)}
# (3, 16.0) {} {(3, 16.0)}
# (2, 19.0) {} {(3, 16.0)}
# ********** (25.0, 27.0) **************
# [(2, 27.0), (1, 27.0)]
# ///////////////////////
# (1, 27.0) {} {(1, 27.0)}
# (2, 27.0) {} {(2, 27.0)}
# (1, 27.0) {} {(2, 27.0)}
# ********** (27.0, 28.0) **************
# [(2, 27.0), (3, 24.0), (2, 28.0), (1, 28.0)]
# ///////////////////////
# (1, 28.0) {} {(1, 28.0)}
# (2, 28.0) {} {(2, 28.0)}
# (1, 28.0) {} {(2, 28.0)}
# (3, 24.0) {} {(3, 24.0)}
# (2, 28.0) {} {(3, 24.0)}
# (2, 27.0) {} {(2, 27.0)}
# (1, 28.0) {} {(2, 27.0)}
# ********** (28.0, 29.0) **************
# [(3, 24.0), (2, 29.0)]
# ///////////////////////
# (2, 29.0) {} {(2, 29.0)}
# (3, 24.0) {} {(3, 24.0)}
# (2, 29.0) {} {(3, 24.0)}
# 4 3 9.0 -1 -1 -1 -1
# edge after 9.0 11.0
# t1p,t2p 9.0 9.0
# 4 3 11.0 -1 -1 -1 -1
# t1p,t2p 9.0 11.0
# 3 1 11.0 9.0 11.0 -2 -1
# edge after 12.0 14.0
# t1p,t2p 12.0 12.0
# 3 1 11.0 9.0 11.0 -2 -1
# t1p,t2p 12.0 14.0
# 4 3 16.0 -1 -1 -1 -1
# t1p,t2p 16.0 16.0
# 4 3 23.0 -1 -1 -1 -1
# edge after 23.0 24.0
# t1p,t2p 23.0 23.0
# 4 3 24.0 -1 -1 -1 -1
# t1p,t2p 23.0 24.0
# 3 2 24.0 23.0 24.0 -2 -1
# edge after 27.0 28.0
# t1p,t2p 27.0 27.0
# 3 2 24.0 23.0 24.0 -2 -1
# edge after 28.0 29.0
# t1p,t2p 27.0 28.0
# 3 2 24.0 23.0 24.0 -2 -1
# t1p,t2p 28.0 29.0
# 4 3 30.0 -1 -1 -1 -1
# edge after 30.0 31.0
# t1p,t2p 30.0 30.0
# 4 3 31.0 -1 -1 -1 -1
# t1p,t2p 30.0 31.0

# %%
bet_moi = bt.read_dictionary("papier_betweenness.pic")

# %%
import os
cmd = 'mv ex-intro_mat.ls archive_code/Test'
os.system(cmd)
# Out:
# 0

# %%
import os
cmd = 'python2 archive_code/betweenness_all.py Test/ex-intro -1 res'
os.system(cmd)
# Out:
# archive_code
# [0.0, 1.0, 2.0, 3.0, 5.0, 6.0, 7.0, 8.0, 9.0, 11.0, 12.0, 14.0, 15.0, 16.0, 18.0, 19.0, 22.0, 23.0, 24.0, 25.0, 27.0, 28.0, 29.0, 30.0, 31.0, 32.0]
# <lslib.LinkStream instance at 0x7f624ab775f0> a a (0.0, 'a') latency [(1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'a', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a c (0.0, 'a') latency [(2.0, 3.0), (8.0, 8.0), (9.0, 9.0), (16.0, 19.0), (24.0, 25.0)]
# ('contri', 'a', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a b (0.0, 'a') latency [(1.0, 1.0), (2.0, 2.0), (9.0, 11.0), (15.0, 15.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0)]
# ('contri', 'a', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a e (0.0, 'a') latency [(2.0, 9.0), (9.0, 16.0), (16.0, 23.0), (24.0, 30.0)]
# ('contri', 'a', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a d (0.0, 'a') latency [(2.0, 6.0), (9.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('contri', 'a', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c a (0.0, 'a') latency [(8.0, 8.0), (9.0, 9.0), (11.0, 15.0), (22.0, 23.0)]
# ('contri', 'c', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c c (0.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'c', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c b (0.0, 'a') latency [(3.0, 3.0), (5.0, 5.0), (11.0, 11.0), (19.0, 19.0), (22.0, 22.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'c', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c e (0.0, 'a') latency [(7.0, 9.0), (11.0, 16.0), (19.0, 23.0), (29.0, 30.0)]
# ('contri', 'c', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c d (0.0, 'a') latency [(6.0, 6.0), (7.0, 7.0), (11.0, 12.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'c', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b a (0.0, 'a') latency [(1.0, 1.0), (2.0, 2.0), (5.0, 8.0), (15.0, 15.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0)]
# ('contri', 'b', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b c (0.0, 'a') latency [(3.0, 3.0), (5.0, 5.0), (11.0, 11.0), (14.0, 18.0), (19.0, 19.0), (22.0, 22.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b b (0.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'b', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b e (0.0, 'a') latency [(5.0, 9.0), (14.0, 16.0), (19.0, 23.0), (28.0, 30.0)]
# ('contri', 'b', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b d (0.0, 'a') latency [(5.0, 6.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e a (0.0, 'a') latency [(11.0, 15.0), (16.0, 23.0)]
# ('contri', 'e', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e c (0.0, 'a') latency [(16.0, 18.0), (24.0, 27.0)]
# ('contri', 'e', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e b (0.0, 'a') latency [(11.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('contri', 'e', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e e (0.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'e', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e d (0.0, 'a') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'e', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d a (0.0, 'a') latency [(7.0, 8.0), (14.0, 15.0), (19.0, 23.0)]
# ('contri', 'd', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d c (0.0, 'a') latency [(6.0, 6.0), (7.0, 7.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'd', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d b (0.0, 'a') latency [(7.0, 11.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'd', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d e (0.0, 'a') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'd', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d d (0.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'd', 'd', ' = ', 0.0)
# {'a': 0.0, 'c': 0.0, 'b': 0.0, 'e': 0.0, 'd': 0.0}
# <lslib.LinkStream instance at 0x7f624ab775f0> a a (1.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# prev []
# next []
# ('contri', 'a', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a c (1.0, 'a') latency [(2.0, 3.0), (8.0, 8.0), (9.0, 9.0), (16.0, 19.0), (24.0, 25.0)]
# ('contri', 'a', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a b (1.0, 'a') latency [(1.0, 1.0), (2.0, 2.0), (9.0, 11.0), (15.0, 15.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0)]
# prev [(0.0, (0.0, 0))]
# next []
# ('left', (0.0, 0))
# ('contri', 'a', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a e (1.0, 'a') latency [(2.0, 9.0), (9.0, 16.0), (16.0, 23.0), (24.0, 30.0)]
# ('contri', 'a', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a d (1.0, 'a') latency [(2.0, 6.0), (9.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('contri', 'a', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c a (1.0, 'a') latency [(8.0, 8.0), (9.0, 9.0), (11.0, 15.0), (22.0, 23.0)]
# ('contri', 'c', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c c (1.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'c', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c b (1.0, 'a') latency [(3.0, 3.0), (5.0, 5.0), (11.0, 11.0), (19.0, 19.0), (22.0, 22.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'c', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c e (1.0, 'a') latency [(7.0, 9.0), (11.0, 16.0), (19.0, 23.0), (29.0, 30.0)]
# ('contri', 'c', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c d (1.0, 'a') latency [(6.0, 6.0), (7.0, 7.0), (11.0, 12.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'c', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b a (1.0, 'a') latency [(1.0, 1.0), (2.0, 2.0), (5.0, 8.0), (15.0, 15.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0)]
# prev [(0.0, (0.0, 0))]
# next []
# ('left', (0.0, 0))
# ('contri', 'b', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b c (1.0, 'a') latency [(3.0, 3.0), (5.0, 5.0), (11.0, 11.0), (14.0, 18.0), (19.0, 19.0), (22.0, 22.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b b (1.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'b', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b e (1.0, 'a') latency [(5.0, 9.0), (14.0, 16.0), (19.0, 23.0), (28.0, 30.0)]
# ('contri', 'b', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b d (1.0, 'a') latency [(5.0, 6.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e a (1.0, 'a') latency [(11.0, 15.0), (16.0, 23.0)]
# ('contri', 'e', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e c (1.0, 'a') latency [(16.0, 18.0), (24.0, 27.0)]
# ('contri', 'e', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e b (1.0, 'a') latency [(11.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('contri', 'e', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e e (1.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'e', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e d (1.0, 'a') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'e', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d a (1.0, 'a') latency [(7.0, 8.0), (14.0, 15.0), (19.0, 23.0)]
# ('contri', 'd', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d c (1.0, 'a') latency [(6.0, 6.0), (7.0, 7.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'd', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d b (1.0, 'a') latency [(7.0, 11.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'd', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d e (1.0, 'a') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'd', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d d (1.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'd', 'd', ' = ', 0.0)
# {'a': 0.0, 'c': 0.0, 'b': 0.0, 'e': 0.0, 'd': 0.0}
# <lslib.LinkStream instance at 0x7f624ab775f0> a a (2.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# prev []
# next []
# ('contri', 'a', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a c (2.0, 'a') latency [(2.0, 3.0), (8.0, 8.0), (9.0, 9.0), (16.0, 19.0), (24.0, 25.0)]
# ('*************///////////// sigma_i', {'a': 1, 'b': 1})
# ('****************//////// vol', {(2.0, 'a'): (1, 0), (2.0, 'b'): (1, 0)})
# ('Dist', {(3.0, 'a'): 0, (2.0, 'a'): 0, (3.0, 'c'): 2, (2.0, 'b'): 1, (3.0, 'b'): 1})
# [('a', 0), ('b', 1)]
# [('a', 0), ('c', 2), ('b', 1)]
# ('reachable', {2.0: ['a', 'b'], 3.0: ['a', 'b', 'c']})
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'c')
# ***************** vol ************************
# {(3.0, 'a'): (1.0, 0), (2.0, 'a'): (1, 0), (3.0, 'c'): (1.0, 0), (2.0, 'b'): (1, 0), (3.0, 'b'): (1.0, 0)}
# ('////////////////////////////////////////////', 3.0, 'c', (1.0, 0))
# ('*************///////////// sigma_i', {'a': 1, 'b': 1})
# ('****************//////// vol', {(2.0, 'a'): (1, 0), (2.0, 'b'): (1, 0)})
# ('Dist', {(3.0, 'a'): 0, (2.0, 'a'): 0, (3.0, 'c'): 2, (2.0, 'b'): 1, (3.0, 'b'): 1})
# [('a', 0), ('b', 1)]
# [('a', 0), ('c', 2), ('b', 1)]
# ('reachable', {2.0: ['a', 'b'], 3.0: ['a', 'b', 'c']})
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'c')
# ***************** vol ************************
# {(3.0, 'a'): (1.0, 0), (2.0, 'a'): (1, 0), (3.0, 'c'): (1.0, 0), (2.0, 'b'): (1, 0), (3.0, 'b'): (1.0, 0)}
# ('////////////////////////////////////////////', 3.0, 'c', (1.0, 0))
# prev [(0.0, (0.0, 0))]
# next [(8.0, (0.0, 0))]
# ('left', (0.0, 0))
# ('right', (0.0, 0))
# ('vol_tv', (1.0, 0), 'denum', (1.0, 0))
# ('contrib', 10.0)
# ('contri', 'a', 'c', ' = ', 10.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a b (2.0, 'a') latency [(1.0, 1.0), (2.0, 2.0), (9.0, 11.0), (15.0, 15.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0)]
# prev []
# next [(15.0, (0.0, 0))]
# ('contri', 'a', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a e (2.0, 'a') latency [(2.0, 9.0), (9.0, 16.0), (16.0, 23.0), (24.0, 30.0)]
# ('*************///////////// sigma_i', {'a': 1, 'b': 1})
# ('****************//////// vol', {(2.0, 'a'): (1, 0), (2.0, 'b'): (1, 0)})
# ('Dist', {(9.0, 'a'): 0, (7.0, 'a'): 0, (2.0, 'a'): 0, (5.0, 'c'): 2, (7.0, 'b'): 1, (8.0, 'c'): 1, (3.0, 'a'): 0, (9.0, 'b'): 1, (6.0, 'c'): 2, (7.0, 'c'): 2, (8.0, 'b'): 1, (3.0, 'b'): 1, (9.0, 'c'): 1, (6.0, 'b'): 1, (5.0, 'a'): 0, (9.0, 'd'): 3, (3.0, 'c'): 2, (8.0, 'a'): 0, (6.0, 'a'): 0, (7.0, 'd'): 3, (2.0, 'b'): 1, (9.0, 'e'): 4, (8.0, 'd'): 3, (6.0, 'd'): 3, (5.0, 'b'): 1})
# [('a', 0), ('b', 1)]
# [('a', 0), ('b', 1), ('c', 2)]
# [('c', 2), ('a', 0), ('b', 1)]
# [('c', 2), ('b', 1), ('a', 0), ('d', 3)]
# [('a', 0), ('b', 1), ('c', 2), ('d', 3)]
# [('c', 1), ('b', 1), ('a', 0), ('d', 3)]
# [('a', 0), ('b', 1), ('c', 1), ('d', 3), ('e', 4)]
# ('reachable', {2.0: ['a', 'b'], 3.0: ['a', 'b', 'c'], 5.0: ['a', 'b', 'c'], 6.0: ['a', 'b', 'c', 'd'], 7.0: ['a', 'b', 'c', 'd'], 8.0: ['a', 'c', 'b', 'd'], 9.0: ['a', 'b', 'c', 'd', 'e']})
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 3.0, 't_prime', 5.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 3.0, 't_prime', 5.0, 'x', 'c')
# ('t', 3.0, 't_prime', 5.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 3.0, 't_prime', 5.0, 'x', 'c')
# ('t', 3.0, 't_prime', 5.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 6.0, 't_prime', 7.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 6.0, 't_prime', 7.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 6.0, 't_prime', 7.0, 'x', 'c')
# ('t', 6.0, 't_prime', 7.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 6.0, 't_prime', 7.0, 'x', 'c')
# ('t', 6.0, 't_prime', 7.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 7.0, 't_prime', 8.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 7.0, 't_prime', 8.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 7.0, 't_prime', 8.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 7.0, 't_prime', 8.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 8.0, 't_prime', 9.0, 'x', 'a')
# ('t', 8.0, 't_prime', 9.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 8.0, 't_prime', 9.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 8.0, 't_prime', 9.0, 'x', 'a')
# ('t', 8.0, 't_prime', 9.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 8.0, 't_prime', 9.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 8.0, 't_prime', 9.0, 'x', 'e')
# ***************** vol ************************
# {(9.0, 'a'): (1.0, 0), (7.0, 'a'): (1.0, 0), (2.0, 'a'): (1, 0), (5.0, 'c'): (2.0, 1), (7.0, 'b'): (1.0, 0), (8.0, 'c'): (1.0, 0), (3.0, 'a'): (1.0, 0), (9.0, 'b'): (1.0, 0), (6.0, 'c'): (2.0, 1), (7.0, 'c'): (2.0, 1), (8.0, 'b'): (1.0, 0), (3.0, 'b'): (1.0, 0), (9.0, 'c'): (1.0, 1), (6.0, 'b'): (1.0, 0), (5.0, 'a'): (1.0, 0), (9.0, 'd'): (2.0, 2), (3.0, 'c'): (1.0, 0), (8.0, 'a'): (1.0, 0), (6.0, 'a'): (1.0, 0), (7.0, 'd'): (2.0, 2), (2.0, 'b'): (1, 0), (9.0, 'e'): (2.0, 2), (8.0, 'd'): (2.0, 2), (6.0, 'd'): (2.0, 1), (5.0, 'b'): (1.0, 0)}
# ('////////////////////////////////////////////', 9.0, 'e', (2.0, 2))
# ('*************///////////// sigma_i', {'a': 1, 'b': 1})
# ('****************//////// vol', {(2.0, 'a'): (1, 0), (2.0, 'b'): (1, 0)})
# ('Dist', {(9.0, 'a'): 0, (7.0, 'a'): 0, (2.0, 'a'): 0, (5.0, 'c'): 2, (7.0, 'b'): 1, (8.0, 'c'): 1, (3.0, 'a'): 0, (9.0, 'b'): 1, (6.0, 'c'): 2, (7.0, 'c'): 2, (8.0, 'b'): 1, (3.0, 'b'): 1, (9.0, 'c'): 1, (6.0, 'b'): 1, (5.0, 'a'): 0, (9.0, 'd'): 3, (3.0, 'c'): 2, (8.0, 'a'): 0, (6.0, 'a'): 0, (7.0, 'd'): 3, (2.0, 'b'): 1, (9.0, 'e'): 4, (8.0, 'd'): 3, (6.0, 'd'): 3, (5.0, 'b'): 1})
# [('a', 0), ('b', 1)]
# [('a', 0), ('b', 1), ('c', 2)]
# [('c', 2), ('a', 0), ('b', 1)]
# [('c', 2), ('b', 1), ('a', 0), ('d', 3)]
# [('a', 0), ('b', 1), ('c', 2), ('d', 3)]
# [('c', 1), ('b', 1), ('a', 0), ('d', 3)]
# [('a', 0), ('b', 1), ('c', 1), ('d', 3), ('e', 4)]
# ('reachable', {2.0: ['a', 'b'], 3.0: ['a', 'b', 'c'], 5.0: ['a', 'b', 'c'], 6.0: ['a', 'b', 'c', 'd'], 7.0: ['a', 'b', 'c', 'd'], 8.0: ['a', 'c', 'b', 'd'], 9.0: ['a', 'b', 'c', 'd', 'e']})
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 3.0, 't_prime', 5.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 3.0, 't_prime', 5.0, 'x', 'c')
# ('t', 3.0, 't_prime', 5.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 3.0, 't_prime', 5.0, 'x', 'c')
# ('t', 3.0, 't_prime', 5.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 6.0, 't_prime', 7.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 6.0, 't_prime', 7.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 6.0, 't_prime', 7.0, 'x', 'c')
# ('t', 6.0, 't_prime', 7.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 6.0, 't_prime', 7.0, 'x', 'c')
# ('t', 6.0, 't_prime', 7.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 7.0, 't_prime', 8.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 7.0, 't_prime', 8.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 7.0, 't_prime', 8.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 7.0, 't_prime', 8.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 8.0, 't_prime', 9.0, 'x', 'a')
# ('t', 8.0, 't_prime', 9.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 8.0, 't_prime', 9.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 8.0, 't_prime', 9.0, 'x', 'a')
# ('t', 8.0, 't_prime', 9.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 8.0, 't_prime', 9.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 8.0, 't_prime', 9.0, 'x', 'e')
# ***************** vol ************************
# {(9.0, 'a'): (1.0, 0), (7.0, 'a'): (1.0, 0), (2.0, 'a'): (1, 0), (5.0, 'c'): (2.0, 1), (7.0, 'b'): (1.0, 0), (8.0, 'c'): (1.0, 0), (3.0, 'a'): (1.0, 0), (9.0, 'b'): (1.0, 0), (6.0, 'c'): (2.0, 1), (7.0, 'c'): (2.0, 1), (8.0, 'b'): (1.0, 0), (3.0, 'b'): (1.0, 0), (9.0, 'c'): (1.0, 1), (6.0, 'b'): (1.0, 0), (5.0, 'a'): (1.0, 0), (9.0, 'd'): (2.0, 2), (3.0, 'c'): (1.0, 0), (8.0, 'a'): (1.0, 0), (6.0, 'a'): (1.0, 0), (7.0, 'd'): (2.0, 2), (2.0, 'b'): (1, 0), (9.0, 'e'): (2.0, 2), (8.0, 'd'): (2.0, 2), (6.0, 'd'): (2.0, 1), (5.0, 'b'): (1.0, 0)}
# ('////////////////////////////////////////////', 9.0, 'e', (2.0, 2))
# ('*************///////////// sigma_i', {'a': 1, 'c': 1})
# ('****************//////// vol', {(9.0, 'c'): (1, 0), (9.0, 'a'): (1, 0)})
# ('Dist', {(12.0, 'c'): 1, (9.0, 'a'): 0, (16.0, 'd'): 3, (15.0, 'c'): 1, (14.0, 'b'): 2, (12.0, 'b'): 2, (16.0, 'c'): 1, (11.0, 'a'): 0, (14.0, 'a'): 0, (15.0, 'd'): 3, (14.0, 'd'): 3, (12.0, 'a'): 0, (9.0, 'c'): 1, (16.0, 'b'): 1, (15.0, 'a'): 0, (11.0, 'b'): 2, (16.0, 'e'): 4, (15.0, 'b'): 1, (11.0, 'c'): 1, (12.0, 'd'): 3, (16.0, 'a'): 0, (14.0, 'c'): 1})
# [('a', 0), ('c', 1)]
# [('a', 0), ('b', 2), ('c', 1)]
# [('c', 1), ('b', 2), ('a', 0), ('d', 3)]
# [('b', 2), ('a', 0), ('d', 3), ('c', 1)]
# [('c', 1), ('d', 3), ('a', 0), ('b', 1)]
# [('d', 3), ('c', 1), ('b', 1), ('e', 4), ('a', 0)]
# ('reachable', {9.0: ['a', 'c'], 11.0: ['a', 'c', 'b'], 12.0: ['a', 'c', 'b', 'd'], 14.0: ['a', 'c', 'b', 'd'], 15.0: ['a', 'c', 'b', 'd'], 16.0: ['a', 'c', 'b', 'd', 'e']})
# ('reachable[t_prime]', ['a', 'c', 'b'])
# ('t', 9.0, 't_prime', 11.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'c', 'b'])
# ('t', 9.0, 't_prime', 11.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'c', 'b'])
# ('t', 9.0, 't_prime', 11.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 11.0, 't_prime', 12.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 11.0, 't_prime', 12.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 11.0, 't_prime', 12.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 11.0, 't_prime', 12.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 12.0, 't_prime', 14.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 12.0, 't_prime', 14.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 12.0, 't_prime', 14.0, 'x', 'b')
# ('t', 12.0, 't_prime', 14.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 12.0, 't_prime', 14.0, 'x', 'b')
# ('t', 12.0, 't_prime', 14.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 14.0, 't_prime', 15.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 14.0, 't_prime', 15.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 14.0, 't_prime', 15.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd'])
# ('t', 14.0, 't_prime', 15.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd', 'e'])
# ('t', 15.0, 't_prime', 16.0, 'x', 'a')
# ('t', 15.0, 't_prime', 16.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd', 'e'])
# ('t', 15.0, 't_prime', 16.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd', 'e'])
# ('t', 15.0, 't_prime', 16.0, 'x', 'a')
# ('t', 15.0, 't_prime', 16.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd', 'e'])
# ('t', 15.0, 't_prime', 16.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'c', 'b', 'd', 'e'])
# ('t', 15.0, 't_prime', 16.0, 'x', 'e')
# ***************** vol ************************
# {(12.0, 'c'): (1.0, 0), (9.0, 'a'): (1, 0), (16.0, 'd'): (2.0, 1), (15.0, 'c'): (1.0, 0), (14.0, 'b'): (1.0, 0), (12.0, 'b'): (1.0, 0), (16.0, 'c'): (1.0, 0), (11.0, 'a'): (1.0, 0), (14.0, 'a'): (1.0, 0), (15.0, 'd'): (2.0, 1), (14.0, 'd'): (2.0, 1), (12.0, 'a'): (1.0, 0), (9.0, 'c'): (1, 0), (16.0, 'b'): (1.0, 1), (15.0, 'a'): (1.0, 0), (11.0, 'b'): (1.0, 0), (16.0, 'e'): (2.0, 1), (15.0, 'b'): (1.0, 0), (11.0, 'c'): (1.0, 0), (12.0, 'd'): (1.0, 0), (16.0, 'a'): (1.0, 0), (14.0, 'c'): (1.0, 0)}
# ('////////////////////////////////////////////', 16.0, 'e', (2.0, 1))
# ('*************///////////// sigma_i', {'a': 1, 'b': 1})
# ('****************//////// vol', {(16.0, 'b'): (1, 0), (16.0, 'a'): (1, 0)})
# ('Dist', {(22.0, 'b'): 1, (18.0, 'a'): 0, (23.0, 'e'): 4, (22.0, 'c'): 2, (18.0, 'b'): 1, (16.0, 'b'): 1, (23.0, 'c'): 2, (22.0, 'd'): 3, (19.0, 'd'): 3, (23.0, 'b'): 1, (19.0, 'c'): 2, (16.0, 'a'): 0, (23.0, 'a'): 0, (19.0, 'b'): 1, (19.0, 'a'): 0, (22.0, 'a'): 0, (23.0, 'd'): 3})
# [('b', 1), ('a', 0)]
# [('a', 0), ('b', 1)]
# [('d', 3), ('c', 2), ('b', 1), ('a', 0)]
# [('b', 1), ('c', 2), ('d', 3), ('a', 0)]
# [('e', 4), ('c', 2), ('b', 1), ('a', 0), ('d', 3)]
# ('reachable', {16.0: ['a', 'b'], 18.0: ['a', 'b'], 19.0: ['a', 'b', 'c', 'd'], 22.0: ['a', 'b', 'c', 'd'], 23.0: ['a', 'b', 'c', 'd', 'e']})
# ('reachable[t_prime]', ['a', 'b'])
# ('t', 16.0, 't_prime', 18.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b'])
# ('t', 16.0, 't_prime', 18.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 18.0, 't_prime', 19.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 18.0, 't_prime', 19.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 18.0, 't_prime', 19.0, 'x', 'c')
# ('t', 18.0, 't_prime', 19.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 18.0, 't_prime', 19.0, 'x', 'c')
# ('t', 18.0, 't_prime', 19.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 19.0, 't_prime', 22.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 19.0, 't_prime', 22.0, 'x', 'c')
# ('t', 19.0, 't_prime', 22.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 19.0, 't_prime', 22.0, 'x', 'c')
# ('t', 19.0, 't_prime', 22.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 19.0, 't_prime', 22.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 22.0, 't_prime', 23.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 22.0, 't_prime', 23.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 22.0, 't_prime', 23.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 22.0, 't_prime', 23.0, 'x', 'd')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd', 'e'])
# ('t', 22.0, 't_prime', 23.0, 'x', 'e')
# ***************** vol ************************
# {(22.0, 'b'): (1.0, 0), (18.0, 'a'): (1.0, 0), (23.0, 'e'): (1.0, 0), (22.0, 'c'): (3.0, 1), (18.0, 'b'): (1.0, 0), (16.0, 'b'): (1, 0), (23.0, 'c'): (3.0, 1), (22.0, 'd'): (1.0, 0), (19.0, 'd'): (1.0, 0), (23.0, 'b'): (2.0, 0), (19.0, 'c'): (1.0, 0), (16.0, 'a'): (1, 0), (23.0, 'a'): (1.0, 0), (19.0, 'b'): (1.0, 0), (19.0, 'a'): (1.0, 0), (22.0, 'a'): (1.0, 0), (23.0, 'd'): (1.0, 0)}
# ('////////////////////////////////////////////', 23.0, 'e', (1.0, 0))
# prev [(0.0, (0.0, 0))]
# next [(16.0, (0.0, 0)), (23.0, (2.0, 1)), (30.0, (2.0, 1))]
# ('left', (0.0, 0))
# ('right', (0.0, 0))
# ('vol_tv', (2.0, 2), 'denum', (2.0, 2))
# ('contrib', 14.0)
# ('right', (2.0, 1))
# ('vol_tv', (2.0, 2), 'denum', (2.0, 2))
# ('contrib', 28.0)
# ('right', (2.0, 1))
# ('vol_tv', (2.0, 2), 'denum', (2.0, 2))
# ('contrib', 42.0)
# ('contri', 'a', 'e', ' = ', 42.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a d (2.0, 'a') latency [(2.0, 6.0), (9.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('*************///////////// sigma_i', {'a': 1, 'b': 1})
# ('****************//////// vol', {(2.0, 'a'): (1, 0), (2.0, 'b'): (1, 0)})
# ('Dist', {(3.0, 'c'): 2, (3.0, 'b'): 1, (3.0, 'a'): 0, (6.0, 'a'): 0, (6.0, 'b'): 1, (2.0, 'a'): 0, (6.0, 'c'): 2, (2.0, 'b'): 1, (5.0, 'a'): 0, (5.0, 'c'): 2, (6.0, 'd'): 3, (5.0, 'b'): 1})
# [('a', 0), ('b', 1)]
# [('c', 2), ('b', 1), ('a', 0)]
# [('a', 0), ('c', 2), ('b', 1)]
# [('a', 0), ('b', 1), ('c', 2), ('d', 3)]
# ('reachable', {2.0: ['a', 'b'], 3.0: ['a', 'b', 'c'], 5.0: ['a', 'b', 'c'], 6.0: ['a', 'b', 'c', 'd']})
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 3.0, 't_prime', 5.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 3.0, 't_prime', 5.0, 'x', 'c')
# ('t', 3.0, 't_prime', 5.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 3.0, 't_prime', 5.0, 'x', 'c')
# ('t', 3.0, 't_prime', 5.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'd')
# ***************** vol ************************
# {(3.0, 'c'): (1.0, 0), (3.0, 'b'): (1.0, 0), (3.0, 'a'): (1.0, 0), (6.0, 'a'): (1.0, 0), (6.0, 'b'): (1.0, 0), (2.0, 'a'): (1, 0), (6.0, 'c'): (2.0, 1), (2.0, 'b'): (1, 0), (5.0, 'a'): (1.0, 0), (5.0, 'c'): (2.0, 1), (6.0, 'd'): (2.0, 1), (5.0, 'b'): (1.0, 0)}
# ('////////////////////////////////////////////', 6.0, 'd', (2.0, 1))
# ('*************///////////// sigma_i', {'a': 1, 'b': 1})
# ('****************//////// vol', {(2.0, 'a'): (1, 0), (2.0, 'b'): (1, 0)})
# ('Dist', {(3.0, 'c'): 2, (3.0, 'b'): 1, (3.0, 'a'): 0, (6.0, 'a'): 0, (6.0, 'b'): 1, (2.0, 'a'): 0, (6.0, 'c'): 2, (2.0, 'b'): 1, (5.0, 'a'): 0, (5.0, 'c'): 2, (6.0, 'd'): 3, (5.0, 'b'): 1})
# [('a', 0), ('b', 1)]
# [('c', 2), ('b', 1), ('a', 0)]
# [('a', 0), ('c', 2), ('b', 1)]
# [('a', 0), ('b', 1), ('c', 2), ('d', 3)]
# ('reachable', {2.0: ['a', 'b'], 3.0: ['a', 'b', 'c'], 5.0: ['a', 'b', 'c'], 6.0: ['a', 'b', 'c', 'd']})
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 2.0, 't_prime', 3.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 3.0, 't_prime', 5.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 3.0, 't_prime', 5.0, 'x', 'c')
# ('t', 3.0, 't_prime', 5.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c'])
# ('t', 3.0, 't_prime', 5.0, 'x', 'c')
# ('t', 3.0, 't_prime', 5.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'a')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'b')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'c')
# ('reachable[t_prime]', ['a', 'b', 'c', 'd'])
# ('t', 5.0, 't_prime', 6.0, 'x', 'd')
# ***************** vol ************************
# {(3.0, 'c'): (1.0, 0), (3.0, 'b'): (1.0, 0), (3.0, 'a'): (1.0, 0), (6.0, 'a'): (1.0, 0), (6.0, 'b'): (1.0, 0), (2.0, 'a'): (1, 0), (6.0, 'c'): (2.0, 1), (2.0, 'b'): (1, 0), (5.0, 'a'): (1.0, 0), (5.0, 'c'): (2.0, 1), (6.0, 'd'): (2.0, 1), (5.0, 'b'): (1.0, 0)}
# ('////////////////////////////////////////////', 6.0, 'd', (2.0, 1))
# prev [(0.0, (0.0, 0))]
# next [(12.0, (0.0, 0))]
# ('left', (0.0, 0))
# ('right', (0.0, 0))
# ('vol_tv', (2.0, 1), 'denum', (2.0, 1))
# ('contrib', 12.0)
# ('contri', 'a', 'd', ' = ', 12.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c a (2.0, 'a') latency [(8.0, 8.0), (9.0, 9.0), (11.0, 15.0), (22.0, 23.0)]
# ('contri', 'c', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c c (2.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'c', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c b (2.0, 'a') latency [(3.0, 3.0), (5.0, 5.0), (11.0, 11.0), (19.0, 19.0), (22.0, 22.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'c', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c e (2.0, 'a') latency [(7.0, 9.0), (11.0, 16.0), (19.0, 23.0), (29.0, 30.0)]
# ('contri', 'c', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c d (2.0, 'a') latency [(6.0, 6.0), (7.0, 7.0), (11.0, 12.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'c', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b a (2.0, 'a') latency [(1.0, 1.0), (2.0, 2.0), (5.0, 8.0), (15.0, 15.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0)]
# prev []
# next [(15.0, (0.0, 0))]
# ('contri', 'b', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b c (2.0, 'a') latency [(3.0, 3.0), (5.0, 5.0), (11.0, 11.0), (14.0, 18.0), (19.0, 19.0), (22.0, 22.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b b (2.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'b', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b e (2.0, 'a') latency [(5.0, 9.0), (14.0, 16.0), (19.0, 23.0), (28.0, 30.0)]
# ('contri', 'b', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b d (2.0, 'a') latency [(5.0, 6.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e a (2.0, 'a') latency [(11.0, 15.0), (16.0, 23.0)]
# ('contri', 'e', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e c (2.0, 'a') latency [(16.0, 18.0), (24.0, 27.0)]
# ('contri', 'e', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e b (2.0, 'a') latency [(11.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('contri', 'e', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e e (2.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'e', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e d (2.0, 'a') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'e', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d a (2.0, 'a') latency [(7.0, 8.0), (14.0, 15.0), (19.0, 23.0)]
# ('contri', 'd', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d c (2.0, 'a') latency [(6.0, 6.0), (7.0, 7.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'd', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d b (2.0, 'a') latency [(7.0, 11.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'd', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d e (2.0, 'a') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'd', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d d (2.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'd', 'd', ' = ', 0.0)
# {'a': 64.0, 'c': 0.0, 'b': 0.0, 'e': 0.0, 'd': 0.0}
# <lslib.LinkStream instance at 0x7f624ab775f0> a a (3.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# prev []
# next []
# ('contri', 'a', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a c (3.0, 'a') latency [(2.0, 3.0), (8.0, 8.0), (9.0, 9.0), (16.0, 19.0), (24.0, 25.0)]
# ('contri', 'a', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a b (3.0, 'a') latency [(1.0, 1.0), (2.0, 2.0), (9.0, 11.0), (15.0, 15.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0)]
# ('contri', 'a', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a e (3.0, 'a') latency [(2.0, 9.0), (9.0, 16.0), (16.0, 23.0), (24.0, 30.0)]
# ('contri', 'a', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a d (3.0, 'a') latency [(2.0, 6.0), (9.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('contri', 'a', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c a (3.0, 'a') latency [(8.0, 8.0), (9.0, 9.0), (11.0, 15.0), (22.0, 23.0)]
# ('contri', 'c', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c c (3.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'c', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c b (3.0, 'a') latency [(3.0, 3.0), (5.0, 5.0), (11.0, 11.0), (19.0, 19.0), (22.0, 22.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'c', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c e (3.0, 'a') latency [(7.0, 9.0), (11.0, 16.0), (19.0, 23.0), (29.0, 30.0)]
# ('contri', 'c', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c d (3.0, 'a') latency [(6.0, 6.0), (7.0, 7.0), (11.0, 12.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'c', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b a (3.0, 'a') latency [(1.0, 1.0), (2.0, 2.0), (5.0, 8.0), (15.0, 15.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0)]
# ('contri', 'b', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b c (3.0, 'a') latency [(3.0, 3.0), (5.0, 5.0), (11.0, 11.0), (14.0, 18.0), (19.0, 19.0), (22.0, 22.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b b (3.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'b', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b e (3.0, 'a') latency [(5.0, 9.0), (14.0, 16.0), (19.0, 23.0), (28.0, 30.0)]
# ('contri', 'b', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b d (3.0, 'a') latency [(5.0, 6.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e a (3.0, 'a') latency [(11.0, 15.0), (16.0, 23.0)]
# ('contri', 'e', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e c (3.0, 'a') latency [(16.0, 18.0), (24.0, 27.0)]
# ('contri', 'e', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e b (3.0, 'a') latency [(11.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('contri', 'e', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e e (3.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'e', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e d (3.0, 'a') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'e', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d a (3.0, 'a') latency [(7.0, 8.0), (14.0, 15.0), (19.0, 23.0)]
# ('contri', 'd', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d c (3.0, 'a') latency [(6.0, 6.0), (7.0, 7.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'd', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d b (3.0, 'a') latency [(7.0, 11.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'd', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d e (3.0, 'a') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'd', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d d (3.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'd', 'd', ' = ', 0.0)
# {'a': 0.0, 'c': 0.0, 'b': 0.0, 'e': 0.0, 'd': 0.0}
# <lslib.LinkStream instance at 0x7f624ab775f0> a a (5.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# prev []
# next []
# ('contri', 'a', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a c (5.0, 'a') latency [(2.0, 3.0), (8.0, 8.0), (9.0, 9.0), (16.0, 19.0), (24.0, 25.0)]
# ('contri', 'a', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a b (5.0, 'a') latency [(1.0, 1.0), (2.0, 2.0), (9.0, 11.0), (15.0, 15.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0)]
# ('contri', 'a', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a e (5.0, 'a') latency [(2.0, 9.0), (9.0, 16.0), (16.0, 23.0), (24.0, 30.0)]
# ('contri', 'a', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a d (5.0, 'a') latency [(2.0, 6.0), (9.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('contri', 'a', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c a (5.0, 'a') latency [(8.0, 8.0), (9.0, 9.0), (11.0, 15.0), (22.0, 23.0)]
# ('contri', 'c', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c c (5.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'c', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c b (5.0, 'a') latency [(3.0, 3.0), (5.0, 5.0), (11.0, 11.0), (19.0, 19.0), (22.0, 22.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'c', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c e (5.0, 'a') latency [(7.0, 9.0), (11.0, 16.0), (19.0, 23.0), (29.0, 30.0)]
# ('contri', 'c', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c d (5.0, 'a') latency [(6.0, 6.0), (7.0, 7.0), (11.0, 12.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'c', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b a (5.0, 'a') latency [(1.0, 1.0), (2.0, 2.0), (5.0, 8.0), (15.0, 15.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0)]
# ('contri', 'b', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b c (5.0, 'a') latency [(3.0, 3.0), (5.0, 5.0), (11.0, 11.0), (14.0, 18.0), (19.0, 19.0), (22.0, 22.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b b (5.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'b', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b e (5.0, 'a') latency [(5.0, 9.0), (14.0, 16.0), (19.0, 23.0), (28.0, 30.0)]
# ('contri', 'b', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b d (5.0, 'a') latency [(5.0, 6.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e a (5.0, 'a') latency [(11.0, 15.0), (16.0, 23.0)]
# ('contri', 'e', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e c (5.0, 'a') latency [(16.0, 18.0), (24.0, 27.0)]
# ('contri', 'e', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e b (5.0, 'a') latency [(11.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('contri', 'e', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e e (5.0, 'a') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'e', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e d (5.0, 'a') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'e', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d a (5.0, 'a') latency [(7.0, 8.0), (14.0, 15.0), (19.0, 23.0)]
# ('contri', 'd', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d c (5.0, 'a') latency [(6.0, 6.0), (7.0, 7.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'd', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d b (5.0, 'a') latency [(7.0, 11.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'd', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d e (5.0, 'a') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'd', 'e', ' = ', 0.0)
# ...
# ('****************//////// vol', {(28.0, 'd'): (1, 0), (28.0, 'c'): (1, 0), (28.0, 'b'): (1, 0)})
# ('Dist', {(28.0, 'd'): 2, (30.0, 'b'): 0, (30.0, 'c'): 1, (28.0, 'b'): 0, (28.0, 'c'): 1, (29.0, 'c'): 1, (30.0, 'd'): 2, (29.0, 'b'): 0, (30.0, 'e'): 3, (29.0, 'd'): 2})
# [('d', 2), ('b', 0), ('c', 1)]
# [('c', 1), ('b', 0), ('d', 2)]
# [('b', 0), ('c', 1), ('d', 2), ('e', 3)]
# ('reachable', {28.0: ['b', 'c', 'd'], 29.0: ['b', 'c', 'd'], 30.0: ['b', 'c', 'd', 'e']})
# ('reachable[t_prime]', ['b', 'c', 'd'])
# ('t', 28.0, 't_prime', 29.0, 'x', 'b')
# ('reachable[t_prime]', ['b', 'c', 'd'])
# ('t', 28.0, 't_prime', 29.0, 'x', 'c')
# ('t', 28.0, 't_prime', 29.0, 'x', 'd')
# ('reachable[t_prime]', ['b', 'c', 'd'])
# ('t', 28.0, 't_prime', 29.0, 'x', 'c')
# ('t', 28.0, 't_prime', 29.0, 'x', 'd')
# ('reachable[t_prime]', ['b', 'c', 'd', 'e'])
# ('t', 29.0, 't_prime', 30.0, 'x', 'b')
# ('reachable[t_prime]', ['b', 'c', 'd', 'e'])
# ('t', 29.0, 't_prime', 30.0, 'x', 'c')
# ('reachable[t_prime]', ['b', 'c', 'd', 'e'])
# ('t', 29.0, 't_prime', 30.0, 'x', 'd')
# ('reachable[t_prime]', ['b', 'c', 'd', 'e'])
# ('t', 29.0, 't_prime', 30.0, 'x', 'e')
# ***************** vol ************************
# {(28.0, 'd'): (1, 0), (30.0, 'b'): (1.0, 0), (30.0, 'c'): (1.0, 0), (28.0, 'b'): (1, 0), (28.0, 'c'): (1, 0), (29.0, 'c'): (1.0, 0), (30.0, 'd'): (1.0, 1), (29.0, 'b'): (1.0, 0), (30.0, 'e'): (1.0, 1), (29.0, 'd'): (1.0, 1)}
# ('////////////////////////////////////////////', 30.0, 'e', (1.0, 1))
# prev [(14.0, (0.0, 0))]
# next [(32.0, (0.0, 0))]
# ('left', (0.0, 0))
# ('right', (0.0, 0))
# ('vol_tv', (1.0, 1), 'denum', (1.0, 1))
# ('contrib', 28.0)
# ('contri', 'b', 'e', ' = ', 28.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b d (30.0, 'e') latency [(5.0, 6.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e a (30.0, 'e') latency [(11.0, 15.0), (16.0, 23.0)]
# ('contri', 'e', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e c (30.0, 'e') latency [(16.0, 18.0), (24.0, 27.0)]
# ('contri', 'e', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e b (30.0, 'e') latency [(11.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('contri', 'e', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e e (30.0, 'e') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0), (32.0, 32.0)]
# prev []
# next []
# ('contri', 'e', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e d (30.0, 'e') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# prev [(24.0, (0.0, 0))]
# next []
# ('left', (0.0, 0))
# ('contri', 'e', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d a (30.0, 'e') latency [(7.0, 8.0), (14.0, 15.0), (19.0, 23.0)]
# ('contri', 'd', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d c (30.0, 'e') latency [(6.0, 6.0), (7.0, 7.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'd', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d b (30.0, 'e') latency [(7.0, 11.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'd', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d e (30.0, 'e') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# prev [(24.0, (0.0, 0))]
# next []
# ('left', (0.0, 0))
# ('contri', 'd', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d d (30.0, 'e') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0), (32.0, 32.0)]
# ('contri', 'd', 'd', ' = ', 0.0)
# {'a': 48.0, 'c': 58.0, 'b': 28.0, 'e': 0.0, 'd': 0.0}
# <lslib.LinkStream instance at 0x7f624ab775f0> a a (31.0, 'e') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0), (32.0, 32.0)]
# ('contri', 'a', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a c (31.0, 'e') latency [(2.0, 3.0), (8.0, 8.0), (9.0, 9.0), (16.0, 19.0), (24.0, 25.0)]
# ('contri', 'a', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a b (31.0, 'e') latency [(1.0, 1.0), (2.0, 2.0), (9.0, 11.0), (15.0, 15.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0)]
# ('contri', 'a', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a e (31.0, 'e') latency [(2.0, 9.0), (9.0, 16.0), (16.0, 23.0), (24.0, 30.0)]
# ('contri', 'a', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a d (31.0, 'e') latency [(2.0, 6.0), (9.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('contri', 'a', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c a (31.0, 'e') latency [(8.0, 8.0), (9.0, 9.0), (11.0, 15.0), (22.0, 23.0)]
# ('contri', 'c', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c c (31.0, 'e') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0), (32.0, 32.0)]
# ('contri', 'c', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c b (31.0, 'e') latency [(3.0, 3.0), (5.0, 5.0), (11.0, 11.0), (19.0, 19.0), (22.0, 22.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'c', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c e (31.0, 'e') latency [(7.0, 9.0), (11.0, 16.0), (19.0, 23.0), (29.0, 30.0)]
# ('contri', 'c', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c d (31.0, 'e') latency [(6.0, 6.0), (7.0, 7.0), (11.0, 12.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'c', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b a (31.0, 'e') latency [(1.0, 1.0), (2.0, 2.0), (5.0, 8.0), (15.0, 15.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0)]
# ('contri', 'b', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b c (31.0, 'e') latency [(3.0, 3.0), (5.0, 5.0), (11.0, 11.0), (14.0, 18.0), (19.0, 19.0), (22.0, 22.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b b (31.0, 'e') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0), (32.0, 32.0)]
# ('contri', 'b', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b e (31.0, 'e') latency [(5.0, 9.0), (14.0, 16.0), (19.0, 23.0), (28.0, 30.0)]
# ('contri', 'b', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b d (31.0, 'e') latency [(5.0, 6.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e a (31.0, 'e') latency [(11.0, 15.0), (16.0, 23.0)]
# ('contri', 'e', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e c (31.0, 'e') latency [(16.0, 18.0), (24.0, 27.0)]
# ('contri', 'e', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e b (31.0, 'e') latency [(11.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('contri', 'e', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e e (31.0, 'e') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0), (32.0, 32.0)]
# prev []
# next []
# ('contri', 'e', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e d (31.0, 'e') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# prev []
# next [(32.0, (0.0, 0))]
# ('contri', 'e', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d a (31.0, 'e') latency [(7.0, 8.0), (14.0, 15.0), (19.0, 23.0)]
# ('contri', 'd', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d c (31.0, 'e') latency [(6.0, 6.0), (7.0, 7.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'd', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d b (31.0, 'e') latency [(7.0, 11.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'd', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d e (31.0, 'e') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# prev []
# next [(32.0, (0.0, 0))]
# ('contri', 'd', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d d (31.0, 'e') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0), (32.0, 32.0)]
# ('contri', 'd', 'd', ' = ', 0.0)
# {'a': 0.0, 'c': 0.0, 'b': 0.0, 'e': 0.0, 'd': 0.0}
# <lslib.LinkStream instance at 0x7f624ab775f0> a a (32.0, 'e') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0), (32.0, 32.0)]
# ('contri', 'a', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a c (32.0, 'e') latency [(2.0, 3.0), (8.0, 8.0), (9.0, 9.0), (16.0, 19.0), (24.0, 25.0)]
# ('contri', 'a', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a b (32.0, 'e') latency [(1.0, 1.0), (2.0, 2.0), (9.0, 11.0), (15.0, 15.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0)]
# ('contri', 'a', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a e (32.0, 'e') latency [(2.0, 9.0), (9.0, 16.0), (16.0, 23.0), (24.0, 30.0)]
# ('contri', 'a', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> a d (32.0, 'e') latency [(2.0, 6.0), (9.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('contri', 'a', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c a (32.0, 'e') latency [(8.0, 8.0), (9.0, 9.0), (11.0, 15.0), (22.0, 23.0)]
# ('contri', 'c', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c c (32.0, 'e') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0), (32.0, 32.0)]
# ('contri', 'c', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c b (32.0, 'e') latency [(3.0, 3.0), (5.0, 5.0), (11.0, 11.0), (19.0, 19.0), (22.0, 22.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'c', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c e (32.0, 'e') latency [(7.0, 9.0), (11.0, 16.0), (19.0, 23.0), (29.0, 30.0)]
# ('contri', 'c', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> c d (32.0, 'e') latency [(6.0, 6.0), (7.0, 7.0), (11.0, 12.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'c', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b a (32.0, 'e') latency [(1.0, 1.0), (2.0, 2.0), (5.0, 8.0), (15.0, 15.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0)]
# ('contri', 'b', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b c (32.0, 'e') latency [(3.0, 3.0), (5.0, 5.0), (11.0, 11.0), (14.0, 18.0), (19.0, 19.0), (22.0, 22.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b b (32.0, 'e') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0), (32.0, 32.0)]
# ('contri', 'b', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b e (32.0, 'e') latency [(5.0, 9.0), (14.0, 16.0), (19.0, 23.0), (28.0, 30.0)]
# ('contri', 'b', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> b d (32.0, 'e') latency [(5.0, 6.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'b', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e a (32.0, 'e') latency [(11.0, 15.0), (16.0, 23.0)]
# ('contri', 'e', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e c (32.0, 'e') latency [(16.0, 18.0), (24.0, 27.0)]
# ('contri', 'e', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e b (32.0, 'e') latency [(11.0, 12.0), (16.0, 19.0), (24.0, 27.0)]
# ('contri', 'e', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e e (32.0, 'e') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0), (32.0, 32.0)]
# prev []
# next []
# ('contri', 'e', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> e d (32.0, 'e') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'e', 'd', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d a (32.0, 'e') latency [(7.0, 8.0), (14.0, 15.0), (19.0, 23.0)]
# ('contri', 'd', 'a', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d c (32.0, 'e') latency [(6.0, 6.0), (7.0, 7.0), (18.0, 18.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0)]
# ('contri', 'd', 'c', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d b (32.0, 'e') latency [(7.0, 11.0), (12.0, 12.0), (14.0, 14.0), (19.0, 19.0), (27.0, 27.0), (28.0, 28.0)]
# ('contri', 'd', 'b', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d e (32.0, 'e') latency [(9.0, 9.0), (11.0, 11.0), (16.0, 16.0), (23.0, 23.0), (24.0, 24.0), (30.0, 30.0), (31.0, 31.0)]
# ('contri', 'd', 'e', ' = ', 0.0)
# <lslib.LinkStream instance at 0x7f624ab775f0> d d (32.0, 'e') latency [(0.0, 0.0), (1.0, 1.0), (2.0, 2.0), (3.0, 3.0), (5.0, 5.0), (6.0, 6.0), (7.0, 7.0), (8.0, 8.0), (9.0, 9.0), (11.0, 11.0), (12.0, 12.0), (14.0, 14.0), (15.0, 15.0), (16.0, 16.0), (18.0, 18.0), (19.0, 19.0), (22.0, 22.0), (23.0, 23.0), (24.0, 24.0), (25.0, 25.0), (27.0, 27.0), (28.0, 28.0), (29.0, 29.0), (30.0, 30.0), (31.0, 31.0), (32.0, 32.0)]
# ('contri', 'd', 'd', ' = ', 0.0)
# {'a': 0.0, 'c': 0.0, 'b': 0.0, 'e': 0.0, 'd': 0.0}
# 0

# %%
bet_mat = bt.read_dictionary("res_betweenness.pic")

# %%
for v in bet_moi.keys():
    for t in bet_moi[v].keys():
        if bet_moi[v][t] != bet_mat[v.lower()][t]:
            print("erreur ",v,t,"=>   ", bet_moi[v][t], bet_mat[v.lower()][t])

# %%
bet_moi['C'][29]
# Out:
# 58.0

# %%
#contribution check
node = 3

# %%
import os
cmd = 'python2 archive_code/betweenness_tout.py Test/ex-intro -1 ' + S.node_to_label[node].lower() + " cont"
os.system(cmd)
# Out:
# 0

# %%
cont_mat = bt.read_dictionary("cont_contri.pic")

# %%
for v in general_contri[node].keys():
    for t in general_contri[node][v].keys():
        if general_contri[node][v][t].val != cont_mat[S.node_to_label[v].lower()][t]:
            print("erreur ",v,t,"=>   ", general_contri[node][v][t].dim,general_contri[node][v][t].val ,cont_mat[S.node_to_label[v].lower()][t])
# Out:
# erreur  1 19.0 =>    0 0 40.0
# erreur  3 19.0 =>    0 45.0 85.0
# erreur  2 19.0 =>    0 45.0 85.0

# %%
cont_mat['b']
# Out:
# {0.0: 0.0,
#  1.0: 0.0,
#  2.0: 0.0,
#  3.0: 0.0,
#  5.0: 0.0,
#  6.0: 0.0,
#  7.0: 0.0,
#  8.0: 0.0,
#  9.0: 0.0,
#  11.0: 7.0,
#  12.0: 0.0,
#  14.0: 178.5,
#  15.0: 178.5,
#  16.0: 0.0,
#  18.0: 0.0,
#  19.0: 40.0,
#  22.0: 45.0,
#  23.0: 45.0,
#  24.0: 0.0,
#  25.0: 0.0,
#  27.0: 0.0,
#  28.0: 0.0,
#  29.0: 0.0,
#  30.0: 0.0,
#  31.0: 0.0,
#  32.0: 0.0}

# %%
general_contri[0][2][29]
# Out:
# vol(0,0)
